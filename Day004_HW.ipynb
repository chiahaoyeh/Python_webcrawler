# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')

# %%
r.text
# Out:
# '[{"id":"22723153535","type":"ReleaseEvent","actor":{"id":959326,"login":"ogoffart","display_login":"ogoffart","gravatar_id":"","url":"https://api.github.com/users/ogoffart","avatar_url":"https://avatars.githubusercontent.com/u/959326?"},"repo":{"id":261124045,"name":"slint-ui/slint","url":"https://api.github.com/repos/slint-ui/slint"},"payload":{"action":"published","release":{"url":"https://api.github.com/repos/slint-ui/slint/releases/71352335","assets_url":"https://api.github.com/repos/slint-ui/slint/releases/71352335/assets","upload_url":"https://uploads.github.com/repos/slint-ui/slint/releases/71352335/assets{?name,label}","html_url":"https://github.com/slint-ui/slint/releases/tag/v0.2.5","id":71352335,"author":{"login":"ogoffart","id":959326,"node_id":"MDQ6VXNlcjk1OTMyNg==","avatar_url":"https://avatars.githubusercontent.com/u/959326?v=4","gravatar_id":"","url":"https://api.github.com/users/ogoffart","html_url":"https://github.com/ogoffart","followers_url":"https://api.github.com/users/ogoffart/followers","following_url":"https://api.github.com/users/ogoffart/following{/other_user}","gists_url":"https://api.github.com/users/ogoffart/gists{/gist_id}","starred_url":"https://api.github.com/users/ogoffart/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ogoffart/subscriptions","organizations_url":"https://api.github.com/users/ogoffart/orgs","repos_url":"https://api.github.com/users/ogoffart/repos","events_url":"https://api.github.com/users/ogoffart/events{/privacy}","received_events_url":"https://api.github.com/users/ogoffart/received_events","type":"User","site_admin":false},"node_id":"RE_kwDOD5Bvzc4EQMAP","tag_name":"v0.2.5","target_commitish":"master","name":"0.2.5","draft":false,"prerelease":false,"created_at":"2022-07-06T08:10:20Z","published_at":"2022-07-06T09:50:04Z","assets":[{"url":"https://api.github.com/repos/slint-ui/slint/releases/assets/70720625","id":70720625,"node_id":"RA_kwDOD5Bvzc4ENxxx","name":"Slint-cpp-0.2.5-Linux-x86_64.tar.gz","label":null,"uploader":{"login":"ogoffart","id":959326,"node_id":"MDQ6VXNlcjk1OTMyNg==","avatar_url":"https://avatars.githubusercontent.com/u/959326?v=4","gravatar_id":"","url":"https://api.github.com/users/ogoffart","html_url":"https://github.com/ogoffart","followers_url":"https://api.github.com/users/ogoffart/followers","following_url":"https://api.github.com/users/ogoffart/following{/other_user}","gists_url":"https://api.github.com/users/ogoffart/gists{/gist_id}","starred_url":"https://api.github.com/users/ogoffart/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ogoffart/subscriptions","organizations_url":"https://api.github.com/users/ogoffart/orgs","repos_url":"https://api.github.com/users/ogoffart/repos","events_url":"https://api.github.com/users/ogoffart/events{/privacy}","received_events_url":"https://api.github.com/users/ogoffart/received_events","type":"User","site_admin":false},"content_type":"application/gzip","state":"uploaded","size":9384247,"download_count":0,"created_at":"2022-07-06T09:44:42Z","updated_at":"2022-07-06T09:44:50Z","browser_download_url":"https://github.com/slint-ui/slint/releases/download/v0.2.5/Slint-cpp-0.2.5-Linux-x86_64.tar.gz"},{"url":"https://api.github.com/repos/slint-ui/slint/releases/assets/70720613","id":70720613,"node_id":"RA_kwDOD5Bvzc4ENxxl","name":"Slint-cpp-0.2.5-win64.exe","label":null,"uploader":{"login":"ogoffart","id":959326,"node_id":"MDQ6VXNlcjk1OTMyNg==","avatar_url":"https://avatars.githubusercontent.com/u/959326?v=4","gravatar_id":"","url":"https://api.github.com/users/ogoffart","html_url":"https://github.com/ogoffart","followers_url":"https://api.github.com/users/ogoffart/followers","following_url":"https://api.github.com/users/ogoffart/following{/other_user}","gists_url":"https://api.github.com/users/ogoffart/gists{/gist_id}","starred_url":"https://api.github.com/users/ogoffart/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ogoffart/subscriptions" ...

# %%
json.loads(r.text)
# Out:
# [{'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/959326?',
#    'display_login': 'ogoffart',
#    'gravatar_id': '',
#    'id': 959326,
#    'login': 'ogoffart',
#    'url': 'https://api.github.com/users/ogoffart'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153535',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/64742117?',
#    'gravatar_id': '',
#    'id': 64742117,
#    'login': 'slint-ui',
#    'url': 'https://api.github.com/orgs/slint-ui'},
#   'payload': {'action': 'published',
#    'release': {'assets': [{'browser_download_url': 'https://github.com/slint-ui/slint/releases/download/v0.2.5/Slint-cpp-0.2.5-Linux-x86_64.tar.gz',
#       'content_type': 'application/gzip',
#       'created_at': '2022-07-06T09:44:42Z',
#       'download_count': 0,
#       'id': 70720625,
#       'label': None,
#       'name': 'Slint-cpp-0.2.5-Linux-x86_64.tar.gz',
#       'node_id': 'RA_kwDOD5Bvzc4ENxxx',
#       'size': 9384247,
#       'state': 'uploaded',
#       'updated_at': '2022-07-06T09:44:50Z',
#       'uploader': {'avatar_url': 'https://avatars.githubusercontent.com/u/959326?v=4',
#        'events_url': 'https://api.github.com/users/ogoffart/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/ogoffart/followers',
#        'following_url': 'https://api.github.com/users/ogoffart/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ogoffart/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/ogoffart',
#        'id': 959326,
#        'login': 'ogoffart',
#        'node_id': 'MDQ6VXNlcjk1OTMyNg==',
#        'organizations_url': 'https://api.github.com/users/ogoffart/orgs',
#        'received_events_url': 'https://api.github.com/users/ogoffart/received_events',
#        'repos_url': 'https://api.github.com/users/ogoffart/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/ogoffart/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ogoffart/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/ogoffart'},
#       'url': 'https://api.github.com/repos/slint-ui/slint/releases/assets/70720625'},
#      {'browser_download_url': 'https://github.com/slint-ui/slint/releases/download/v0.2.5/Slint-cpp-0.2.5-win64.exe',
#       'content_type': 'application/x-ms-dos-executable',
#       'created_at': '2022-07-06T09:44:32Z',
#       'download_count': 0,
#       'id': 70720613,
#       'label': None,
#       'name': 'Slint-cpp-0.2.5-win64.exe',
#       'node_id': 'RA_kwDOD5Bvzc4ENxxl',
#       'size': 12089046,
#       'state': 'uploaded',
#       'updated_at': '2022-07-06T09:44:42Z',
#       'uploader': {'avatar_url': 'https://avatars.githubusercontent.com/u/959326?v=4',
#        'events_url': 'https://api.github.com/users/ogoffart/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/ogoffart/followers',
#        'following_url': 'https://api.github.com/users/ogoffart/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ogoffart/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/ogoffart',
#        'id': 959326,
#        'login': 'ogoffart',
#        'node_id': 'MDQ6VXNlcjk1OTMyNg==',
#        'organizations_url': 'https://api.github.com/users/ogoffart/orgs',
#        'received_events_url': 'https://api.github.com/users/ogoffart/received_events',
#        'repos_url': 'https://api.github.com/users/ogoffart/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/ogoffart/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ogoffart/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/ogoffart'},
#       'url': 'https://api.github.com/repos/slint-ui/slint/releases/assets/70720613'},
#      {'browser_download_url': 'https://github.com/slint-ui/slint/releases/download/v0.2.5/slint-lsp-linux.tar.gz',
#       'content_type': 'application/gzip',
#       'created_at': '2022-07-06T09:44:50Z',
#       'download_count': 0,
#       'id': 70720632,
#       'label': None,
#       'name': 'slint-lsp-linux.tar.gz',
#       'node_id': 'RA_kwDOD5Bvzc4ENxx4',
#       'size': 4073755,
#       'state': 'uploaded',
#       'updated_at': '2022-07-06T09:44:54Z',
#       'uploader': {'avatar_url': 'https://avatars.githubusercontent.com/u/959326?v=4',
#        'events_url': 'https://api.github.com/users/ogoffart/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/ogoffart/followers',
#        'following_url': 'https://api.github.com/users/ogoffart/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ogoffart/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/ogoffart',
#        'id': 959326,
#        'login': 'ogoffart',
#        'node_id': 'MDQ6VXNlcjk1OTMyNg==',
#        'organizations_url': 'https://api.github.com/users/ogoffart/orgs',
#        'received_events_url': 'https://api.github.com/users/ogoffart/received_events',
#        'repos_url': 'https://api.github.com/users/ogoffart/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/ogoffart/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ogoffart/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/ogoffart'},
#       'url': 'https://api.github.com/repos/slint-ui/slint/releases/assets/70720632'},
#      {'browser_download_url': 'https://github.com/slint-ui/slint/releases/download/v0.2.5/slint-lsp-windows.zip',
#       'content_type': 'application/zip',
#       'created_at': '2022-07-06T09:44:21Z',
#       'download_count': 0,
#       'id': 70720591,
#       'label': None,
#       'name': 'slint-lsp-windows.zip',
#       'node_id': 'RA_kwDOD5Bvzc4ENxxP',
#       'size': 12329930,
#       'state': 'uploaded',
#       'updated_at': '2022-07-06T09:44:32Z',
#       'uploader': {'avatar_url': 'https://avatars.githubusercontent.com/u/959326?v=4',
#        'events_url': 'https://api.github.com/users/ogoffart/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/ogoffart/followers',
#        'following_url': 'https://api.github.com/users/ogoffart/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ogoffart/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/ogoffart',
#        'id': 959326,
#        'login': 'ogoffart',
#        'node_id': 'MDQ6VXNlcjk1OTMyNg==',
#        'organizations_url': 'https://api.github.com/users/ogoffart/orgs',
#        'received_events_url': 'https://api.github.com/users/ogoffart/received_events',
#        'repos_url': 'https://api.github.com/users/ogoffart/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/ogoffart/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ogoffart/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/ogoffart'},
#       'url': 'https://api.github.com/repos/slint-ui/slint/releases/assets/70720591'},
#      {'browser_download_url': 'https://github.com/slint-ui/slint/releases/download/v0.2.5/slint-viewer-linux.tar.gz',
#       'content_type': 'application/gzip',
#       'created_at': '2022-07-06T09:44:54Z',
#       'download_count': 0,
#       'id': 70720640,
#       'label': None,
#       'name': 'slint-viewer-linux.tar.gz',
#       'node_id': 'RA_kwDOD5Bvzc4ENxyA',
#       'size': 4154429,
#       'state': 'uploaded',
#       'updated_at': '2022-07-06T09:44:58Z',
#       'uploader': {'avatar_url': 'https://avatars.githubusercontent.com/u/959326?v=4',
#        'events_url': 'https://api.github.com/users/ogoffart/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/ogoffart/followers',
#        'following_url': 'https://api.github.com/users/ogoffart/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ogoffart/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/ogoffart',
#        'id': 959326,
#        'login': 'ogoffart',
#        'node_id': 'MDQ6VXNlcjk1OTMyNg==',
#        'organizations_url': 'https://api.github.com/users/ogoffart/orgs',
#        'received_events_url': 'https://api.github.com/users/ogoffart/received_events',
#        'repos_url': 'https://api.github.com/users/ogoffart/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/ogoffart/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ogoffart/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/ogoffart'},
#       'url': 'https://api.github.com/repos/slint-ui/slint/releases/assets/70720640'},
#      {'browser_download_url': 'https://github.com/slint-ui/slint/releases/download/v0.2.5/slint-viewer-windows.zip',
#       'content_type': 'application/zip',
#       'created_at': '2022-07-06T09:44:10Z',
#       'download_count': 0,
#       'id': 70720567,
#       'label': None,
#       'name': 'slint-viewer-windows.zip',
#       'node_id': 'RA_kwDOD5Bvzc4ENxw3',
#       'size': 12313570,
#       'state': 'uploaded',
#       'updated_at': '2022-07-06T09:44:21Z',
#       'uploader': {'avatar_url': 'https://avatars.githubusercontent.com/u/959326?v=4',
#        'events_url': 'https://api.github.com/users/ogoffart/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/ogoffart/followers',
#        'following_url': 'https://api.github.com/users/ogoffart/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ogoffart/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/ogoffart',
#        'id': 959326,
#        'login': 'ogoffart',
#        'node_id': 'MDQ6VXNlcjk1OTMyNg==',
#        'organizations_url': 'https://api.github.com/users/ogoffart/orgs',
#        'received_events_url': 'https://api.github.com/users/ogoffart/received_events',
#        'repos_url': 'https://api.github.com/users/ogoffart/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/ogoffart/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ogoffart/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/ogoffart'},
#       'url': 'https://api.github.com/repos/slint-ui/slint/releases/assets/70720567'}],
#     'assets_url': 'https://api.github.com/repos/slint-ui/slint/releases/71352335/assets',
#     'author': {'avatar_url': 'https://avatars.githubusercontent.com/u/959326?v=4',
#      'events_url': 'https://api.github.com/users/ogoffart/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/ogoffart/followers',
#      'following_url': 'https://api.github.com/users/ogoffart/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ogoffart/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/ogoffart',
#      'id': 959326,
#      'login': 'ogoffart',
#      'node_id': 'MDQ6VXNlcjk1OTMyNg==',
#      'organizations_url': 'https://api.github.com/users/ogoffart/orgs',
#      'received_events_url': 'https://api.github.com/users/ogoffart/received_events',
#      'repos_url': 'https://api.github.com/users/ogoffart/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/ogoffart/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ogoffart/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/ogoffart'},
#     'body': 'This is the 0.2.5 release\r\n\r\n[Changelog](https://github.com/slint-ui/slint/blob/master/CHANGELOG.md#025---2022-07-06)',
#     'created_at': '2022-07-06T08:10:20Z',
#     'draft': False,
#     'html_url': 'https://github.com/slint-ui/slint/releases/tag/v0.2.5',
#     'id': 71352335,
#     'is_short_description_html_truncated': False,
#     'name': '0.2.5',
#     'node_id': 'RE_kwDOD5Bvzc4EQMAP',
#     'prerelease': False,
#     'published_at': '2022-07-06T09:50:04Z',
#     'short_description_html': '<p>This is the 0.2.5 release</p>\n<p><a href="https://github.com/slint-ui/slint/blob/master/CHANGELOG.md#025---2022-07-06">Changelog</a></p>',
#     'tag_name': 'v0.2.5',
#     'tarball_url': 'https://api.github.com/repos/slint-ui/slint/tarball/v0.2.5',
#     'target_commitish': 'master',
#     'upload_url': 'https://uploads.github.com/repos/slint-ui/slint/releases/71352335/assets{?name,label}',
#     'url': 'https://api.github.com/repos/slint-ui/slint/releases/71352335',
#     'zipball_url': 'https://api.github.com/repos/slint-ui/slint/zipball/v0.2.5'}},
#   'public': True,
#   'repo': {'id': 261124045,
#    'name': 'slint-ui/slint',
#    'url': 'https://api.github.com/repos/slint-ui/slint'},
#   'type': 'ReleaseEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'id': 8517910,
#    'login': 'LombiqBot',
#    'url': 'https://api.github.com/users/LombiqBot'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153678',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?',
#    'gravatar_id': '',
#    'id': 8158177,
#    'login': 'Lombiq',
#    'url': 'https://api.github.com/orgs/Lombiq'},
#   'payload': {'before': '248cc7ecde173fa9776d0dc69098c498f4134698',
#    'commits': [],
#    'distinct_size': 0,
#    'head': '248cc7ecde173fa9776d0dc69098c498f4134698',
#    'push_id': 10359838624,
#    'ref': 'refs/heads/feature/webpi',
#    'size': 0},
#   'public': True,
#   'repo': {'id': 86929735,
#    'name': 'Lombiq/Orchard',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/32507116?',
#    'display_login': 'Thomas-Malh',
#    'gravatar_id': '',
#    'id': 32507116,
#    'login': 'Thomas-Malh',
#    'url': 'https://api.github.com/users/Thomas-Malh'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153677',
#   'payload': {'before': '71bdae4e2588cba4ca897be817d7c560f1875b36',
#    'commits': [{'author': {'email': 'ubuntu@knm.red', 'name': 'ubuntu'},
#      'distinct': True,
#      'message': 'Wed 06 Jul 2022 11:50:02 AM CEST',
#      'sha': '760577ec15ab1485b75daaee692241fee3b006d5',
#      'url': 'https://api.github.com/repos/Thomas-Malh/Thomas-Malh/commits/760577ec15ab1485b75daaee692241fee3b006d5'}],
#    'distinct_size': 1,
#    'head': '760577ec15ab1485b75daaee692241fee3b006d5',
#    'push_id': 10359838615,
#    'ref': 'refs/heads/main',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 478275335,
#    'name': 'Thomas-Malh/Thomas-Malh',
#    'url': 'https://api.github.com/repos/Thomas-Malh/Thomas-Malh'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/108798553?',
#    'display_login': 'bomvb',
#    'gravatar_id': '',
#    'id': 108798553,
#    'login': 'bomvb',
#    'url': 'https://api.github.com/users/bomvb'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153637',
#   'payload': {'description': None,
#    'master_branch': 'main',
#    'pusher_type': 'user',
#    'ref': 'main',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 511078873,
#    'name': 'bomvb/bomvb.github.io',
#    'url': 'https://api.github.com/repos/bomvb/bomvb.github.io'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/99167659?',
#    'display_login': 'TeresaKnudsen',
#    'gravatar_id': '',
#    'id': 99167659,
#    'login': 'TeresaKnudsen',
#    'url': 'https://api.github.com/users/TeresaKnudsen'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153676',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/60601058?',
#    'gravatar_id': '',
#    'id': 60601058,
#    'login': 'brickmanlab',
#    'url': 'https://api.github.com/orgs/brickmanlab'},
#   'payload': {'description': None,
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': 'master',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 511079394,
#    'name': 'brickmanlab/knudsen_et_al_2022',
#    'url': 'https://api.github.com/repos/brickmanlab/knudsen_et_al_2022'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/54195112?',
#    'display_login': 'Beginagain0430',
#    'gravatar_id': '',
#    'id': 54195112,
#    'login': 'Beginagain0430',
#    'url': 'https://api.github.com/users/Beginagain0430'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153631',
#   'payload': {'action': 'started'},
#   'public': True,
#   'repo': {'id': 41526025,
#    'name': 'mzlogin/chinese-copywriting-guidelines',
#    'url': 'https://api.github.com/repos/mzlogin/chinese-copywriting-guidelines'},
#   'type': 'WatchEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'id': 41898282,
#    'login': 'github-actions[bot]',
#    'url': 'https://api.github.com/users/github-actions[bot]'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153643',
#   'payload': {'before': 'b89aaee63391dbbdb6a9862d8d9385c4cf19d38e',
#    'commits': [{'author': {'email': 'thuraucsy@users.noreply.github.com',
#       'name': 'thuraucsy'},
#      'distinct': True,
#      'message': 'Deploying to gh-pages from  @ 4cba1b473d2fcc1f9e7adf537f122e50d670abd1 🚀',
#      'sha': '37c58d42fae0d239c990e3c8a6c5f05afd998c62',
#      'url': 'https://api.github.com/repos/thuraucsy/yen_zay/commits/37c58d42fae0d239c990e3c8a6c5f05afd998c62'}],
#    'distinct_size': 1,
#    'head': '37c58d42fae0d239c990e3c8a6c5f05afd998c62',
#    'push_id': 10359838533,
#    'ref': 'refs/heads/gh-pages',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 37443011,
#    'name': 'thuraucsy/yen_zay',
#    'url': 'https://api.github.com/repos/thuraucsy/yen_zay'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/87640748?',
#    'display_login': 'JohanCSmit',
#    'gravatar_id': '',
#    'id': 87640748,
#    'login': 'JohanCSmit',
#    'url': 'https://api.github.com/users/JohanCSmit'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153603',
#   'payload': {'before': 'f2e623bda54755f1702be2bd033aead2beac5902',
#    'commits': [{'author': {'email': 'karletsebeth@gmail.com', 'name': 'Karl'},
#      'distinct': False,
#      'message': 'Added events and rudimentary IOS compatibility mode',
#      'sha': '9611cb11dd07c02b1b21169541f4c55432ca81f7',
#      'url': 'https://api.github.com/repos/JohanCSmit/Maverick/commits/9611cb11dd07c02b1b21169541f4c55432ca81f7'},
#     {'author': {'email': 'karletsebeth@gmail.com', 'name': 'Karl'},
#      'distinct': False,
#      'message': "Merge branch 'IOSCompatibility' into develop",
#      'sha': '737a0ffe0d956b51b918a01aa2fe13ff6aed6c1a',
#      'url': 'https://api.github.com/repos/JohanCSmit/Maverick/commits/737a0ffe0d956b51b918a01aa2fe13ff6aed6c1a'},
#     {'author': {'email': 'karletsebeth@gmail.com', 'name': 'Karl'},
#      'distinct': False,
#      'message': 'Fixed IOS and Android devices going to sleep while playing',
#      'sha': 'a06142825704d8011ca4861ce7b780fa537d7ba9',
#      'url': 'https://api.github.com/repos/JohanCSmit/Maverick/commits/a06142825704d8011ca4861ce7b780fa537d7ba9'},
#     {'author': {'email': 'karletsebeth@gmail.com', 'name': 'Karl'},
#      'distinct': False,
#      'message': "Merge branch 'stopSleeping' into develop",
#      'sha': 'ce421a908ef3e03f796e43eb1ecea78324ad61af',
#      'url': 'https://api.github.com/repos/JohanCSmit/Maverick/commits/ce421a908ef3e03f796e43eb1ecea78324ad61af'},
#     {'author': {'email': 'jsjohansmit6@gmail.com', 'name': 'Johan Smit'},
#      'distinct': False,
#      'message': "Merge branch 'main' into develop",
#      'sha': 'a37f1a17cd5994298a9b8d28ed02c53b8ab015a5',
#      'url': 'https://api.github.com/repos/JohanCSmit/Maverick/commits/a37f1a17cd5994298a9b8d28ed02c53b8ab015a5'},
#     {'author': {'email': 'jsjohansmit6@gmail.com', 'name': 'Johan Smit'},
#      'distinct': True,
#      'message': "Merge branch 'develop' into main",
#      'sha': '2887149f3346b6921a34de644c2d7f72cfb23993',
#      'url': 'https://api.github.com/repos/JohanCSmit/Maverick/commits/2887149f3346b6921a34de644c2d7f72cfb23993'}],
#    'distinct_size': 1,
#    'head': '2887149f3346b6921a34de644c2d7f72cfb23993',
#    'push_id': 10359838550,
#    'ref': 'refs/heads/main',
#    'size': 6},
#   'public': True,
#   'repo': {'id': 510760077,
#    'name': 'JohanCSmit/Maverick',
#    'url': 'https://api.github.com/repos/JohanCSmit/Maverick'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/67564159?',
#    'display_login': 'coastranges',
#    'gravatar_id': '',
#    'id': 67564159,
#    'login': 'coastranges',
#    'url': 'https://api.github.com/users/coastranges'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153644',
#   'payload': {'before': '254a5c5b3dc7ce8f49db33dfec20acca403aaa6c',
#    'commits': [{'author': {'email': 'farwest49@hotmail.com',
#       'name': 'coastranges'},
#      'distinct': True,
#      'message': 'new_data',
#      'sha': 'c566fc703580fa57573f1c954960799b9a726d20',
#      'url': 'https://api.github.com/repos/coastranges/olivehill/commits/c566fc703580fa57573f1c954960799b9a726d20'}],
#    'distinct_size': 1,
#    'head': 'c566fc703580fa57573f1c954960799b9a726d20',
#    'push_id': 10359838582,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 279324303,
#    'name': 'coastranges/olivehill',
#    'url': 'https://api.github.com/repos/coastranges/olivehill'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/3519946?',
#    'display_login': 'Alcazer',
#    'gravatar_id': '',
#    'id': 3519946,
#    'login': 'Alcazer',
#    'url': 'https://api.github.com/users/Alcazer'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153663',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/12230362?',
#    'gravatar_id': '',
#    'id': 12230362,
#    'login': 'TechnitiumSoftware',
#    'url': 'https://api.github.com/orgs/TechnitiumSoftware'},
#   'payload': {'action': 'opened',
#    'number': 429,
#    'pull_request': {'_links': {'comments': {'href': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/issues/429/comments'},
#      'commits': {'href': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/pulls/429/commits'},
#      'html': {'href': 'https://github.com/TechnitiumSoftware/DnsServer/pull/429'},
#      'issue': {'href': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/issues/429'},
#      'review_comment': {'href': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/pulls/comments{/number}'},
#      'review_comments': {'href': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/pulls/429/comments'},
#      'self': {'href': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/pulls/429'},
#      'statuses': {'href': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/statuses/d8813d3393b3d31735c4fc091076425fafe22dea'}},
#     'active_lock_reason': None,
#     'additions': 4,
#     'assignee': None,
#     'assignees': [],
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'base': {'label': 'TechnitiumSoftware:master',
#      'ref': 'master',
#      'repo': {'allow_forking': True,
#       'archive_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/branches{/branch}',
#       'clone_url': 'https://github.com/TechnitiumSoftware/DnsServer.git',
#       'collaborators_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/contributors',
#       'created_at': '2017-10-29T10:56:47Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/deployments',
#       'description': 'Technitium DNS Server',
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/downloads',
#       'events_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/events',
#       'fork': False,
#       'forks': 172,
#       'forks_count': 172,
#       'forks_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/forks',
#       'full_name': 'TechnitiumSoftware/DnsServer',
#       'git_commits_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/git/tags{/sha}',
#       'git_url': 'git://github.com/TechnitiumSoftware/DnsServer.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': 'https://technitium.com/dns/',
#       'hooks_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/hooks',
#       'html_url': 'https://github.com/TechnitiumSoftware/DnsServer',
#       'id': 108726321,
#       'is_template': False,
#       'issue_comment_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/labels{/name}',
#       'language': 'C#',
#       'languages_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/languages',
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'node_id': 'MDc6TGljZW5zZTk=',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0'},
#       'merges_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/merges',
#       'milestones_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/milestones{/number}',
#       'mirror_url': None,
#       'name': 'DnsServer',
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMDg3MjYzMjE=',
#       'notifications_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/notifications{?since,all,participating}',
#       'open_issues': 34,
#       'open_issues_count': 34,
#       'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/12230362?v=4',
#        'events_url': 'https://api.github.com/users/TechnitiumSoftware/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/TechnitiumSoftware/followers',
#        'following_url': 'https://api.github.com/users/TechnitiumSoftware/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/TechnitiumSoftware/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/TechnitiumSoftware',
#        'id': 12230362,
#        'login': 'TechnitiumSoftware',
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyMjMwMzYy',
#        'organizations_url': 'https://api.github.com/users/TechnitiumSoftware/orgs',
#        'received_events_url': 'https://api.github.com/users/TechnitiumSoftware/received_events',
#        'repos_url': 'https://api.github.com/users/TechnitiumSoftware/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/TechnitiumSoftware/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/TechnitiumSoftware/subscriptions',
#        'type': 'Organization',
#        'url': 'https://api.github.com/users/TechnitiumSoftware'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/pulls{/number}',
#       'pushed_at': '2022-07-03T11:17:29Z',
#       'releases_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/releases{/id}',
#       'size': 4074,
#       'ssh_url': 'git@github.com:TechnitiumSoftware/DnsServer.git',
#       'stargazers_count': 1100,
#       'stargazers_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/stargazers',
#       'statuses_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/subscribers',
#       'subscription_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/subscription',
#       'svn_url': 'https://github.com/TechnitiumSoftware/DnsServer',
#       'tags_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/tags',
#       'teams_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/teams',
#       'topics': ['cross-platform',
#        'dhcp-server',
#        'dns',
#        'dns-client',
#        'dns-over-https',
#        'dns-over-tls',
#        'dns-over-tor',
#        'dns-server',
#        'dotnet',
#        'privacy',
#        'technitium-dns-server'],
#       'trees_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/git/trees{/sha}',
#       'updated_at': '2022-07-05T08:26:16Z',
#       'url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer',
#       'visibility': 'public',
#       'watchers': 1100,
#       'watchers_count': 1100,
#       'web_commit_signoff_required': False},
#      'sha': 'b7181dea699918a489626303e0dc049a747bf5f5',
#      'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/12230362?v=4',
#       'events_url': 'https://api.github.com/users/TechnitiumSoftware/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/TechnitiumSoftware/followers',
#       'following_url': 'https://api.github.com/users/TechnitiumSoftware/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/TechnitiumSoftware/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/TechnitiumSoftware',
#       'id': 12230362,
#       'login': 'TechnitiumSoftware',
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyMjMwMzYy',
#       'organizations_url': 'https://api.github.com/users/TechnitiumSoftware/orgs',
#       'received_events_url': 'https://api.github.com/users/TechnitiumSoftware/received_events',
#       'repos_url': 'https://api.github.com/users/TechnitiumSoftware/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/TechnitiumSoftware/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/TechnitiumSoftware/subscriptions',
#       'type': 'Organization',
#       'url': 'https://api.github.com/users/TechnitiumSoftware'}},
#     'body': "Dns Server wasn't working properly in service mode. Based on the logs, i saw that it was missing.\r\n\r\nI tested it by changing the DnsService.runtimeconfig.json and it worked fine.",
#     'changed_files': 1,
#     'closed_at': None,
#     'comments': 0,
#     'comments_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/issues/429/comments',
#     'commits': 1,
#     'commits_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/pulls/429/commits',
#     'created_at': '2022-07-06T09:50:04Z',
#     'deletions': 0,
#     'diff_url': 'https://github.com/TechnitiumSoftware/DnsServer/pull/429.diff',
#     'draft': False,
#     'head': {'label': 'Alcazer:missing',
#      'ref': 'missing',
#      'repo': {'allow_forking': True,
#       'archive_url': 'https://api.github.com/repos/Alcazer/DnsServer/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/Alcazer/DnsServer/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/Alcazer/DnsServer/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/Alcazer/DnsServer/branches{/branch}',
#       'clone_url': 'https://github.com/Alcazer/DnsServer.git',
#       'collaborators_url': 'https://api.github.com/repos/Alcazer/DnsServer/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/Alcazer/DnsServer/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/Alcazer/DnsServer/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/Alcazer/DnsServer/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/Alcazer/DnsServer/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/Alcazer/DnsServer/contributors',
#       'created_at': '2022-07-06T09:49:17Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/Alcazer/DnsServer/deployments',
#       'description': 'Technitium DNS Server',
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/Alcazer/DnsServer/downloads',
#       'events_url': 'https://api.github.com/repos/Alcazer/DnsServer/events',
#       'fork': True,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/Alcazer/DnsServer/forks',
#       'full_name': 'Alcazer/DnsServer',
#       'git_commits_url': 'https://api.github.com/repos/Alcazer/DnsServer/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Alcazer/DnsServer/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Alcazer/DnsServer/git/tags{/sha}',
#       'git_url': 'git://github.com/Alcazer/DnsServer.git',
#       'has_downloads': True,
#       'has_issues': False,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': 'https://technitium.com/dns/',
#       'hooks_url': 'https://api.github.com/repos/Alcazer/DnsServer/hooks',
#       'html_url': 'https://github.com/Alcazer/DnsServer',
#       'id': 511079134,
#       'is_template': False,
#       'issue_comment_url': 'https://api.github.com/repos/Alcazer/DnsServer/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/Alcazer/DnsServer/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/Alcazer/DnsServer/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/Alcazer/DnsServer/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/Alcazer/DnsServer/labels{/name}',
#       'language': None,
#       'languages_url': 'https://api.github.com/repos/Alcazer/DnsServer/languages',
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'node_id': 'MDc6TGljZW5zZTk=',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0'},
#       'merges_url': 'https://api.github.com/repos/Alcazer/DnsServer/merges',
#       'milestones_url': 'https://api.github.com/repos/Alcazer/DnsServer/milestones{/number}',
#       'mirror_url': None,
#       'name': 'DnsServer',
#       'node_id': 'R_kgDOHnZy3g',
#       'notifications_url': 'https://api.github.com/repos/Alcazer/DnsServer/notifications{?since,all,participating}',
#       'open_issues': 0,
#       'open_issues_count': 0,
#       'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/3519946?v=4',
#        'events_url': 'https://api.github.com/users/Alcazer/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/Alcazer/followers',
#        'following_url': 'https://api.github.com/users/Alcazer/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Alcazer/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/Alcazer',
#        'id': 3519946,
#        'login': 'Alcazer',
#        'node_id': 'MDQ6VXNlcjM1MTk5NDY=',
#        'organizations_url': 'https://api.github.com/users/Alcazer/orgs',
#        'received_events_url': 'https://api.github.com/users/Alcazer/received_events',
#        'repos_url': 'https://api.github.com/users/Alcazer/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/Alcazer/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Alcazer/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/Alcazer'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/Alcazer/DnsServer/pulls{/number}',
#       'pushed_at': '2022-07-06T09:49:40Z',
#       'releases_url': 'https://api.github.com/repos/Alcazer/DnsServer/releases{/id}',
#       'size': 4074,
#       'ssh_url': 'git@github.com:Alcazer/DnsServer.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/Alcazer/DnsServer/stargazers',
#       'statuses_url': 'https://api.github.com/repos/Alcazer/DnsServer/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/Alcazer/DnsServer/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Alcazer/DnsServer/subscription',
#       'svn_url': 'https://github.com/Alcazer/DnsServer',
#       'tags_url': 'https://api.github.com/repos/Alcazer/DnsServer/tags',
#       'teams_url': 'https://api.github.com/repos/Alcazer/DnsServer/teams',
#       'topics': [],
#       'trees_url': 'https://api.github.com/repos/Alcazer/DnsServer/git/trees{/sha}',
#       'updated_at': '2022-07-05T08:26:16Z',
#       'url': 'https://api.github.com/repos/Alcazer/DnsServer',
#       'visibility': 'public',
#       'watchers': 0,
#       'watchers_count': 0,
#       'web_commit_signoff_required': False},
#      'sha': 'd8813d3393b3d31735c4fc091076425fafe22dea',
#      'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/3519946?v=4',
#       'events_url': 'https://api.github.com/users/Alcazer/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/Alcazer/followers',
#       'following_url': 'https://api.github.com/users/Alcazer/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Alcazer/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/Alcazer',
#       'id': 3519946,
#       'login': 'Alcazer',
#       'node_id': 'MDQ6VXNlcjM1MTk5NDY=',
#       'organizations_url': 'https://api.github.com/users/Alcazer/orgs',
#       'received_events_url': 'https://api.github.com/users/Alcazer/received_events',
#       'repos_url': 'https://api.github.com/users/Alcazer/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/Alcazer/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Alcazer/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/Alcazer'}},
#     'html_url': 'https://github.com/TechnitiumSoftware/DnsServer/pull/429',
#     'id': 988569391,
#     'issue_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/issues/429',
#     'labels': [],
#     'locked': False,
#     'maintainer_can_modify': True,
#     'merge_commit_sha': None,
#     'mergeable': None,
#     'mergeable_state': 'unknown',
#     'merged': False,
#     'merged_at': None,
#     'merged_by': None,
#     'milestone': None,
#     'node_id': 'PR_kwDOBnsIMc467F8v',
#     'number': 429,
#     'patch_url': 'https://github.com/TechnitiumSoftware/DnsServer/pull/429.patch',
#     'rebaseable': None,
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'review_comment_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/pulls/comments{/number}',
#     'review_comments': 0,
#     'review_comments_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/pulls/429/comments',
#     'state': 'open',
#     'statuses_url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/statuses/d8813d3393b3d31735c4fc091076425fafe22dea',
#     'title': 'Missing Windows Service Globalization Invariant',
#     'updated_at': '2022-07-06T09:50:04Z',
#     'url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer/pulls/429',
#     'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/3519946?v=4',
#      'events_url': 'https://api.github.com/users/Alcazer/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/Alcazer/followers',
#      'following_url': 'https://api.github.com/users/Alcazer/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Alcazer/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/Alcazer',
#      'id': 3519946,
#      'login': 'Alcazer',
#      'node_id': 'MDQ6VXNlcjM1MTk5NDY=',
#      'organizations_url': 'https://api.github.com/users/Alcazer/orgs',
#      'received_events_url': 'https://api.github.com/users/Alcazer/received_events',
#      'repos_url': 'https://api.github.com/users/Alcazer/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/Alcazer/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Alcazer/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/Alcazer'}}},
#   'public': True,
#   'repo': {'id': 108726321,
#    'name': 'TechnitiumSoftware/DnsServer',
#    'url': 'https://api.github.com/repos/TechnitiumSoftware/DnsServer'},
#   'type': 'PullRequestEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/94978369?',
#    'display_login': 'Venkat3823',
#    'gravatar_id': '',
#    'id': 94978369,
#    'login': 'Venkat3823',
#    'url': 'https://api.github.com/users/Venkat3823'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153596',
#   'payload': {'before': 'f11fdcb79d57b79e7b63754b988665dcf3474cbf',
#    'commits': [{'author': {'email': 'venkatgamingzone48@gmail.com',
#       'name': 'Venkat3823'},
#      'distinct': True,
#      'message': 'Kaali-Linux : Loop 07/06/22-09:50:02am',
#      'sha': 'b637784bb48e5ce9f996b7398c144bc100a43f17',
#      'url': 'https://api.github.com/repos/Venkat3823/Kaali-Linux/commits/b637784bb48e5ce9f996b7398c144bc100a43f17'}],
#    'distinct_size': 1,
#    'head': 'b637784bb48e5ce9f996b7398c144bc100a43f17',
#    'push_id': 10359838556,
#    'ref': 'refs/heads/kaali-linux',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 510217396,
#    'name': 'Venkat3823/Kaali-Linux',
#    'url': 'https://api.github.com/repos/Venkat3823/Kaali-Linux'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'id': 41898282,
#    'login': 'github-actions[bot]',
#    'url': 'https://api.github.com/users/github-actions[bot]'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153559',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/14176906?',
#    'gravatar_id': '',
#    'id': 14176906,
#    'login': 'paritytech',
#    'url': 'https://api.github.com/orgs/paritytech'},
#   'payload': {'before': 'ac391b7b59efc5913791dc0485d6c371d527a67b',
#    'commits': [{'author': {'email': 'NachoPal@users.noreply.github.com',
#       'name': 'NachoPal'},
#      'distinct': True,
#      'message': 'deploy: a47caa1ebc409c7c06991291c48910d70f829d6d',
#      'sha': 'c204b0a4cb2bda37b2f32469405535c83aec48f4',
#      'url': 'https://api.github.com/repos/paritytech/cumulus/commits/c204b0a4cb2bda37b2f32469405535c83aec48f4'}],
#    'distinct_size': 1,
#    'head': 'c204b0a4cb2bda37b2f32469405535c83aec48f4',
#    'push_id': 10359838489,
#    'ref': 'refs/heads/gh-pages',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 165911534,
#    'name': 'paritytech/cumulus',
#    'url': 'https://api.github.com/repos/paritytech/cumulus'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/12682868?',
#    'display_login': 'somenewsforyou',
#    'gravatar_id': '',
#    'id': 12682868,
#    'login': 'somenewsforyou',
#    'url': 'https://api.github.com/users/somenewsforyou'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153595',
#   'payload': {'before': '0103f7a0f223bc084cd8796a6df238904dcc53a1',
#    'commits': [{'author': {'email': 'n4gyg4b0r@protonmail.ch',
#       'name': 'somenewsforyou'},
#      'distinct': True,
#      'message': 'upgrade',
#      'sha': '8cd27c46d1f18d64c0866c6d4c3d4f8935d225d3',
#      'url': 'https://api.github.com/repos/somenewsforyou/somenewsforyou.github.io/commits/8cd27c46d1f18d64c0866c6d4c3d4f8935d225d3'}],
#    'distinct_size': 1,
#    'head': '8cd27c46d1f18d64c0866c6d4c3d4f8935d225d3',
#    'push_id': 10359838557,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 36606153,
#    'name': 'somenewsforyou/somenewsforyou.github.io',
#    'url': 'https://api.github.com/repos/somenewsforyou/somenewsforyou.github.io'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/62687145?',
#    'display_login': 'vpnsuperapp',
#    'gravatar_id': '',
#    'id': 62687145,
#    'login': 'vpnsuperapp',
#    'url': 'https://api.github.com/users/vpnsuperapp'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153542',
#   'payload': {'before': 'c235e0ac220572908b2b6c7255e16a6eb801c4a7',
#    'commits': [{'author': {'email': '62687145+vpnsuperapp@users.noreply.github.com',
#       'name': 'vpnsuperapp'},
#      'distinct': True,
#      'message': 'thank you',
#      'sha': '5bea5f46c744fa8eb7ebb40b3ea34c7d51aaf791',
#      'url': 'https://api.github.com/repos/vpnsuperapp/fast/commits/5bea5f46c744fa8eb7ebb40b3ea34c7d51aaf791'}],
#    'distinct_size': 1,
#    'head': '5bea5f46c744fa8eb7ebb40b3ea34c7d51aaf791',
#    'push_id': 10359838530,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 250208038,
#    'name': 'vpnsuperapp/fast',
#    'url': 'https://api.github.com/repos/vpnsuperapp/fast'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/35613825?',
#    'display_login': 'vercel',
#    'gravatar_id': '',
#    'id': 35613825,
#    'login': 'vercel[bot]',
#    'url': 'https://api.github.com/users/vercel[bot]'},
#   'created_at': '2022-07-06T09:50:04Z',
#   'id': '22723153593',
#   'payload': {'comment': {'author_association': 'NONE',
#     'body': 'Successfully deployed to the following URLs:\n\n## nextjs-porfolio – ./\n\n[nextjs-porfolio-fabrizioonorio.vercel.app](https://nextjs-porfolio-fabrizioonorio.vercel.app)  \n[nextjs-porfolio.vercel.app](https://nextjs-porfolio.vercel.app)  \n[nextjs-porfolio-git-main-fabrizioonorio.vercel.app](https://nextjs-porfolio-git-main-fabrizioonorio.vercel.app)  \n[www.fabrizio.digital](https://www.fabrizio.digital)  \n[fabrizio.digital](https://fabrizio.digital)',
#     'commit_id': 'b1fc88ecb57bd104391b847939a33685a9329463',
#     'created_at': '2022-07-06T09:50:04Z',
#     'html_url': 'https://github.com/FabrizioOnorio/nextjs-porfolio/commit/b1fc88ecb57bd104391b847939a33685a9329463#commitcomment-77807676',
#     'id': 77807676,
#     'line': None,
#     'node_id': 'CC_kwDOHT5qss4Eo0A8',
#     'path': None,
#     'position': None,
#     'reactions': {'+1': 0,
#      '-1': 0,
#      'confused': 0,
#      'eyes': 0,
#      'heart': 0,
#      'hooray': 0,
#      'laugh': 0,
#      'rocket': 0,
#      'total_count': 0,
#      'url': 'https://api.github.com/repos/FabrizioOnorio/nextjs-porfolio/comments/77807676/reactions'},
#     'updated_at': '2022-07-06T09:50:04Z',
#     'url': 'https://api.github.com/repos/FabrizioOnorio/nextjs-porfolio/comments/77807676',
#     'user': {'avatar_url': 'https://avatars.githubusercontent.com/in/8329?v=4',
#      'events_url': 'https://api.github.com/users/vercel%5Bbot%5D/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/vercel%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/vercel%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vercel%5Bbot%5D/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/apps/vercel',
#      'id': 35613825,
#      'login': 'vercel[bot]',
#      'node_id': 'MDM6Qm90MzU2MTM4MjU=',
#      'organizations_url': 'https://api.github.com/users/vercel%5Bbot%5D/orgs',
#      'received_events_url': 'https://api.github.com/users/vercel%5Bbot%5D/received_events',
#      'repos_url': 'https://api.github.com/users/vercel%5Bbot%5D/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/vercel%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vercel%5Bbot%5D/subscriptions',
#      'type': 'Bot',
#      'url': 'https://api.github.com/users/vercel%5Bbot%5D'}}},
#   'public': True,
# ...
#       'blobs_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/branches{/branch}',
#       'clone_url': 'https://github.com/akdfkeks/TooDooFE.git',
#       'collaborators_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/contributors',
#       'created_at': '2022-05-02T08:13:13Z',
#       'default_branch': 'main',
#       'deployments_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/deployments',
#       'description': None,
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/downloads',
#       'events_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/events',
#       'fork': False,
#       'forks': 1,
#       'forks_count': 1,
#       'forks_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/forks',
#       'full_name': 'akdfkeks/TooDooFE',
#       'git_commits_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/git/tags{/sha}',
#       'git_url': 'git://github.com/akdfkeks/TooDooFE.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': None,
#       'hooks_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/hooks',
#       'html_url': 'https://github.com/akdfkeks/TooDooFE',
#       'id': 487766131,
#       'is_template': False,
#       'issue_comment_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/labels{/name}',
#       'language': 'JavaScript',
#       'languages_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/languages',
#       'license': None,
#       'merges_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/merges',
#       'milestones_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/milestones{/number}',
#       'mirror_url': None,
#       'name': 'TooDooFE',
#       'node_id': 'R_kgDOHRK4cw',
#       'notifications_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/notifications{?since,all,participating}',
#       'open_issues': 1,
#       'open_issues_count': 1,
#       'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/52886761?v=4',
#        'events_url': 'https://api.github.com/users/akdfkeks/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/akdfkeks/followers',
#        'following_url': 'https://api.github.com/users/akdfkeks/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/akdfkeks/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/akdfkeks',
#        'id': 52886761,
#        'login': 'akdfkeks',
#        'node_id': 'MDQ6VXNlcjUyODg2NzYx',
#        'organizations_url': 'https://api.github.com/users/akdfkeks/orgs',
#        'received_events_url': 'https://api.github.com/users/akdfkeks/received_events',
#        'repos_url': 'https://api.github.com/users/akdfkeks/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/akdfkeks/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/akdfkeks/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/akdfkeks'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/pulls{/number}',
#       'pushed_at': '2022-07-06T05:12:58Z',
#       'releases_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/releases{/id}',
#       'size': 262,
#       'ssh_url': 'git@github.com:akdfkeks/TooDooFE.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/stargazers',
#       'statuses_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/subscribers',
#       'subscription_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/subscription',
#       'svn_url': 'https://github.com/akdfkeks/TooDooFE',
#       'tags_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/tags',
#       'teams_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/teams',
#       'topics': [],
#       'trees_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/git/trees{/sha}',
#       'updated_at': '2022-07-04T02:13:08Z',
#       'url': 'https://api.github.com/repos/akdfkeks/TooDooFE',
#       'visibility': 'public',
#       'watchers': 0,
#       'watchers_count': 0,
#       'web_commit_signoff_required': False},
#      'sha': '562eddfdaa325fc2124dc2b16f074f1cff1452e2',
#      'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/52886761?v=4',
#       'events_url': 'https://api.github.com/users/akdfkeks/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/akdfkeks/followers',
#       'following_url': 'https://api.github.com/users/akdfkeks/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/akdfkeks/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/akdfkeks',
#       'id': 52886761,
#       'login': 'akdfkeks',
#       'node_id': 'MDQ6VXNlcjUyODg2NzYx',
#       'organizations_url': 'https://api.github.com/users/akdfkeks/orgs',
#       'received_events_url': 'https://api.github.com/users/akdfkeks/received_events',
#       'repos_url': 'https://api.github.com/users/akdfkeks/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/akdfkeks/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/akdfkeks/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/akdfkeks'}},
#     'body': '.',
#     'changed_files': 5,
#     'closed_at': None,
#     'comments': 0,
#     'comments_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/issues/7/comments',
#     'commits': 1,
#     'commits_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/pulls/7/commits',
#     'created_at': '2022-07-06T09:50:03Z',
#     'deletions': 71,
#     'diff_url': 'https://github.com/akdfkeks/TooDooFE/pull/7.diff',
#     'draft': False,
#     'head': {'label': 'akdfkeks:lhh_0706',
#      'ref': 'lhh_0706',
#      'repo': {'allow_forking': True,
#       'archive_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/branches{/branch}',
#       'clone_url': 'https://github.com/akdfkeks/TooDooFE.git',
#       'collaborators_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/contributors',
#       'created_at': '2022-05-02T08:13:13Z',
#       'default_branch': 'main',
#       'deployments_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/deployments',
#       'description': None,
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/downloads',
#       'events_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/events',
#       'fork': False,
#       'forks': 1,
#       'forks_count': 1,
#       'forks_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/forks',
#       'full_name': 'akdfkeks/TooDooFE',
#       'git_commits_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/git/tags{/sha}',
#       'git_url': 'git://github.com/akdfkeks/TooDooFE.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': None,
#       'hooks_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/hooks',
#       'html_url': 'https://github.com/akdfkeks/TooDooFE',
#       'id': 487766131,
#       'is_template': False,
#       'issue_comment_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/labels{/name}',
#       'language': 'JavaScript',
#       'languages_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/languages',
#       'license': None,
#       'merges_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/merges',
#       'milestones_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/milestones{/number}',
#       'mirror_url': None,
#       'name': 'TooDooFE',
#       'node_id': 'R_kgDOHRK4cw',
#       'notifications_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/notifications{?since,all,participating}',
#       'open_issues': 1,
#       'open_issues_count': 1,
#       'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/52886761?v=4',
#        'events_url': 'https://api.github.com/users/akdfkeks/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/akdfkeks/followers',
#        'following_url': 'https://api.github.com/users/akdfkeks/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/akdfkeks/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/akdfkeks',
#        'id': 52886761,
#        'login': 'akdfkeks',
#        'node_id': 'MDQ6VXNlcjUyODg2NzYx',
#        'organizations_url': 'https://api.github.com/users/akdfkeks/orgs',
#        'received_events_url': 'https://api.github.com/users/akdfkeks/received_events',
#        'repos_url': 'https://api.github.com/users/akdfkeks/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/akdfkeks/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/akdfkeks/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/akdfkeks'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/pulls{/number}',
#       'pushed_at': '2022-07-06T05:12:58Z',
#       'releases_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/releases{/id}',
#       'size': 262,
#       'ssh_url': 'git@github.com:akdfkeks/TooDooFE.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/stargazers',
#       'statuses_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/subscribers',
#       'subscription_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/subscription',
#       'svn_url': 'https://github.com/akdfkeks/TooDooFE',
#       'tags_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/tags',
#       'teams_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/teams',
#       'topics': [],
#       'trees_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/git/trees{/sha}',
#       'updated_at': '2022-07-04T02:13:08Z',
#       'url': 'https://api.github.com/repos/akdfkeks/TooDooFE',
#       'visibility': 'public',
#       'watchers': 0,
#       'watchers_count': 0,
#       'web_commit_signoff_required': False},
#      'sha': 'b2af41493bb30e2101fe985fb29f5dcd93cecff3',
#      'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/52886761?v=4',
#       'events_url': 'https://api.github.com/users/akdfkeks/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/akdfkeks/followers',
#       'following_url': 'https://api.github.com/users/akdfkeks/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/akdfkeks/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/akdfkeks',
#       'id': 52886761,
#       'login': 'akdfkeks',
#       'node_id': 'MDQ6VXNlcjUyODg2NzYx',
#       'organizations_url': 'https://api.github.com/users/akdfkeks/orgs',
#       'received_events_url': 'https://api.github.com/users/akdfkeks/received_events',
#       'repos_url': 'https://api.github.com/users/akdfkeks/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/akdfkeks/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/akdfkeks/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/akdfkeks'}},
#     'html_url': 'https://github.com/akdfkeks/TooDooFE/pull/7',
#     'id': 988569385,
#     'issue_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/issues/7',
#     'labels': [],
#     'locked': False,
#     'maintainer_can_modify': False,
#     'merge_commit_sha': None,
#     'mergeable': None,
#     'mergeable_state': 'unknown',
#     'merged': False,
#     'merged_at': None,
#     'merged_by': None,
#     'milestone': None,
#     'node_id': 'PR_kwDOHRK4c8467F8p',
#     'number': 7,
#     'patch_url': 'https://github.com/akdfkeks/TooDooFE/pull/7.patch',
#     'rebaseable': None,
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'review_comment_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/pulls/comments{/number}',
#     'review_comments': 0,
#     'review_comments_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/pulls/7/comments',
#     'state': 'open',
#     'statuses_url': 'https://api.github.com/repos/akdfkeks/TooDooFE/statuses/b2af41493bb30e2101fe985fb29f5dcd93cecff3',
#     'title': '.',
#     'updated_at': '2022-07-06T09:50:03Z',
#     'url': 'https://api.github.com/repos/akdfkeks/TooDooFE/pulls/7',
#     'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/52886761?v=4',
#      'events_url': 'https://api.github.com/users/akdfkeks/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/akdfkeks/followers',
#      'following_url': 'https://api.github.com/users/akdfkeks/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/akdfkeks/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/akdfkeks',
#      'id': 52886761,
#      'login': 'akdfkeks',
#      'node_id': 'MDQ6VXNlcjUyODg2NzYx',
#      'organizations_url': 'https://api.github.com/users/akdfkeks/orgs',
#      'received_events_url': 'https://api.github.com/users/akdfkeks/received_events',
#      'repos_url': 'https://api.github.com/users/akdfkeks/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/akdfkeks/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/akdfkeks/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/akdfkeks'}}},
#   'public': True,
#   'repo': {'id': 487766131,
#    'name': 'akdfkeks/TooDooFE',
#    'url': 'https://api.github.com/repos/akdfkeks/TooDooFE'},
#   'type': 'PullRequestEvent'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json

cat = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(cat.text)
# Out:
# [{'__v': 0,
#   '_id': '5887e1d85c873e0011036889',
#   'createdAt': '2018-01-15T21:20:00.003Z',
#   'deleted': False,
#   'source': 'user',
#   'status': {'feedback': '', 'sentCount': 1, 'verified': True},
#   'text': 'Cats make about 100 different sounds. Dogs make only about 10.',
#   'type': 'cat',
#   'updatedAt': '2020-09-03T16:39:39.578Z',
#   'used': True,
#   'user': '5a9ac18c7478810ea6c06381'},
#  {'__v': 0,
#   '_id': '588e746706ac2b00110e59ff',
#   'createdAt': '2018-01-14T21:20:02.750Z',
#   'deleted': False,
#   'source': 'user',
#   'status': {'sentCount': 1, 'verified': True},
#   'text': 'Domestic cats spend about 70 percent of the day sleeping and 15 percent of the day grooming.',
#   'type': 'cat',
#   'updatedAt': '2020-08-26T20:20:02.359Z',
#   'used': True,
#   'user': '588e6e8806ac2b00110e59c3'},
#  {'__v': 0,
#   '_id': '58923f2fc3878c0011784c79',
#   'createdAt': '2018-02-25T21:20:03.060Z',
#   'deleted': False,
#   'source': 'user',
#   'status': {'sentCount': 1, 'verified': True},
#   'text': "I don't know anything about cats.",
#   'type': 'cat',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'used': False,
#   'user': '5887e9f65c873e001103688d'},
#  {'__v': 0,
#   '_id': '5894af975cdc7400113ef7f9',
#   'createdAt': '2018-02-27T21:20:02.854Z',
#   'deleted': False,
#   'source': 'user',
#   'status': {'sentCount': 1, 'verified': True},
#   'text': 'The technical term for a cat’s hairball is a bezoar.',
#   'type': 'cat',
#   'updatedAt': '2020-11-25T21:20:03.895Z',
#   'used': True,
#   'user': '5a9ac18c7478810ea6c06381'},
#  {'__v': 0,
#   '_id': '58e007cc0aac31001185ecf5',
#   'createdAt': '2018-03-01T21:20:02.713Z',
#   'deleted': False,
#   'source': 'user',
#   'status': {'sentCount': 1, 'verified': True},
#   'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#   'type': 'cat',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'used': False,
#   'user': '58e007480aac31001185ecef'}]
