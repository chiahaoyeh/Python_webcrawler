# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"22722876845","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":473567167,"name":"CompeyDev/discord-status-action","url":"https://api.github.com/repos/CompeyDev/discord-status-action"},"payload":{"push_id":10359703877,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"a65ba4ad35c7a92b34b91371ae4519218d1e184b","before":"40e6175d17fba422c7853c1952aa9cfec2f8c13a","commits":[{"sha":"a65ba4ad35c7a92b34b91371ae4519218d1e184b","author":{"email":"hi@devcomp.tk","name":"StatsBot"},"message":"🚀 Update Discord Status","distinct":true,"url":"https://api.github.com/repos/CompeyDev/discord-status-action/commits/a65ba4ad35c7a92b34b91371ae4519218d1e184b"}]},"public":true,"created_at":"2022-07-06T09:36:44Z"},{"id":"22722876767","type":"PushEvent","actor":{"id":54496822,"login":"B7Bprog","display_login":"B7Bprog","gravatar_id":"","url":"https://api.github.com/users/B7Bprog","avatar_url":"https://avatars.githubusercontent.com/u/54496822?"},"repo":{"id":510294628,"name":"B7Bprog/NC-Games","url":"https://api.github.com/repos/B7Bprog/NC-Games"},"payload":{"push_id":10359703839,"size":1,"distinct_size":1,"ref":"refs/heads/ticket-7","head":"4d7d6975bcc114d0bb46b6dd3d01d7aabfe2f041","before":"ffccb84f38c80c85713e8d63c4a554305d95f479","commits":[{"sha":"4d7d6975bcc114d0bb46b6dd3d01d7aabfe2f041","author":{"email":"belabertalan@gmail.com","name":"Bela Bertalan"},"message":"Added new test to check comment count where there\'s no comment, also refactored code.","distinct":true,"url":"https://api.github.com/repos/B7Bprog/NC-Games/commits/4d7d6975bcc114d0bb46b6dd3d01d7aabfe2f041"}]},"public":true,"created_at":"2022-07-06T09:36:44Z"},{"id":"22722876816","type":"PushEvent","actor":{"id":5288046,"login":"antongolub","display_login":"antongolub","gravatar_id":"","url":"https://api.github.com/users/antongolub","avatar_url":"https://avatars.githubusercontent.com/u/5288046?"},"repo":{"id":372608739,"name":"qiwi/zx-extra","url":"https://api.github.com/repos/qiwi/zx-extra"},"payload":{"push_id":10359703852,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"966fce16034f6a0abebc9cc32cd819652cf0d0b1","before":"53827db878eec0a0b508724e251a35e82b22ff98","commits":[{"sha":"966fce16034f6a0abebc9cc32cd819652cf0d0b1","author":{"email":"antongolub@antongolub.com","name":"Anton"},"message":"fix(ver): try both `-v` and `--version` flags to get bin version","distinct":true,"url":"https://api.github.com/repos/qiwi/zx-extra/commits/966fce16034f6a0abebc9cc32cd819652cf0d0b1"}]},"public":true,"created_at":"2022-07-06T09:36:44Z","org":{"id":4426465,"login":"qiwi","gravatar_id":"","url":"https://api.github.com/orgs/qiwi","avatar_url":"https://avatars.githubusercontent.com/u/4426465?"}},{"id":"22722876786","type":"IssueCommentEvent","actor":{"id":7165771,"login":"pedrobaeza","display_login":"pedrobaeza","gravatar_id":"","url":"https://api.github.com/users/pedrobaeza","avatar_url":"https://avatars.githubusercontent.com/u/7165771?"},"repo":{"id":20920616,"name":"OCA/l10n-spain","url":"https://api.github.com/repos/OCA/l10n-spain"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/OCA/l10n-spain/issues/2398","repository_url":"https://api.github.com/repos/OCA/l10n-spain","labels_url":"https://api.github.com/repos/OCA/l10n-spain/issues/2398/labels{/name}","comments_url":"https://api.github.com/repos/OCA/l10n-spain/issues/2398/comments","events_url":"https://api.github.com/repos/OCA/l10n-spain/issues/2398/events","html_url":"https://github.com/OCA/l10n-spain/pull/2398","id":1295538372,"node_id":"PR_kwDOAT85KM466-Ir","number":2398,"title":"[15.0][FIX] l10n_es_facturae: minor translation fixes (forward port)","user":{"login":"MiquelRForgeFlow","id":25005517,"node_id":"MDQ6VXNlcjI1MDA1NTE3","avatar_url":"https://avatars.githubusercontent.com/u ...

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json

r = requests.get('https://api.github.com/events')
json.loads(r.text)
# Out:
# [{'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'id': 41898282,
#    'login': 'github-actions[bot]',
#    'url': 'https://api.github.com/users/github-actions[bot]'},
#   'created_at': '2022-07-06T09:36:44Z',
#   'id': '22722876845',
#   'payload': {'before': '40e6175d17fba422c7853c1952aa9cfec2f8c13a',
#    'commits': [{'author': {'email': 'hi@devcomp.tk', 'name': 'StatsBot'},
#      'distinct': True,
#      'message': '🚀 Update Discord Status',
#      'sha': 'a65ba4ad35c7a92b34b91371ae4519218d1e184b',
#      'url': 'https://api.github.com/repos/CompeyDev/discord-status-action/commits/a65ba4ad35c7a92b34b91371ae4519218d1e184b'}],
#    'distinct_size': 1,
#    'head': 'a65ba4ad35c7a92b34b91371ae4519218d1e184b',
#    'push_id': 10359703877,
#    'ref': 'refs/heads/main',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 473567167,
#    'name': 'CompeyDev/discord-status-action',
#    'url': 'https://api.github.com/repos/CompeyDev/discord-status-action'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/54496822?',
#    'display_login': 'B7Bprog',
#    'gravatar_id': '',
#    'id': 54496822,
#    'login': 'B7Bprog',
#    'url': 'https://api.github.com/users/B7Bprog'},
#   'created_at': '2022-07-06T09:36:44Z',
#   'id': '22722876767',
#   'payload': {'before': 'ffccb84f38c80c85713e8d63c4a554305d95f479',
#    'commits': [{'author': {'email': 'belabertalan@gmail.com',
#       'name': 'Bela Bertalan'},
#      'distinct': True,
#      'message': "Added new test to check comment count where there's no comment, also refactored code.",
#      'sha': '4d7d6975bcc114d0bb46b6dd3d01d7aabfe2f041',
#      'url': 'https://api.github.com/repos/B7Bprog/NC-Games/commits/4d7d6975bcc114d0bb46b6dd3d01d7aabfe2f041'}],
#    'distinct_size': 1,
#    'head': '4d7d6975bcc114d0bb46b6dd3d01d7aabfe2f041',
#    'push_id': 10359703839,
#    'ref': 'refs/heads/ticket-7',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 510294628,
#    'name': 'B7Bprog/NC-Games',
#    'url': 'https://api.github.com/repos/B7Bprog/NC-Games'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/5288046?',
#    'display_login': 'antongolub',
#    'gravatar_id': '',
#    'id': 5288046,
#    'login': 'antongolub',
#    'url': 'https://api.github.com/users/antongolub'},
#   'created_at': '2022-07-06T09:36:44Z',
#   'id': '22722876816',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/4426465?',
#    'gravatar_id': '',
#    'id': 4426465,
#    'login': 'qiwi',
#    'url': 'https://api.github.com/orgs/qiwi'},
#   'payload': {'before': '53827db878eec0a0b508724e251a35e82b22ff98',
#    'commits': [{'author': {'email': 'antongolub@antongolub.com',
#       'name': 'Anton'},
#      'distinct': True,
#      'message': 'fix(ver): try both `-v` and `--version` flags to get bin version',
#      'sha': '966fce16034f6a0abebc9cc32cd819652cf0d0b1',
#      'url': 'https://api.github.com/repos/qiwi/zx-extra/commits/966fce16034f6a0abebc9cc32cd819652cf0d0b1'}],
#    'distinct_size': 1,
#    'head': '966fce16034f6a0abebc9cc32cd819652cf0d0b1',
#    'push_id': 10359703852,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 372608739,
#    'name': 'qiwi/zx-extra',
#    'url': 'https://api.github.com/repos/qiwi/zx-extra'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/7165771?',
#    'display_login': 'pedrobaeza',
#    'gravatar_id': '',
#    'id': 7165771,
#    'login': 'pedrobaeza',
#    'url': 'https://api.github.com/users/pedrobaeza'},
#   'created_at': '2022-07-06T09:36:44Z',
#   'id': '22722876786',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/7600578?',
#    'gravatar_id': '',
#    'id': 7600578,
#    'login': 'OCA',
#    'url': 'https://api.github.com/orgs/OCA'},
#   'payload': {'action': 'created',
#    'comment': {'author_association': 'MEMBER',
#     'body': '/ocabot merge minor',
#     'created_at': '2022-07-06T09:36:44Z',
#     'html_url': 'https://github.com/OCA/l10n-spain/pull/2398#issuecomment-1176006545',
#     'id': 1176006545,
#     'issue_url': 'https://api.github.com/repos/OCA/l10n-spain/issues/2398',
#     'node_id': 'IC_kwDOAT85KM5GGG-R',
#     'performed_via_github_app': None,
#     'reactions': {'+1': 0,
#      '-1': 0,
#      'confused': 0,
#      'eyes': 0,
#      'heart': 0,
#      'hooray': 0,
#      'laugh': 0,
#      'rocket': 0,
#      'total_count': 0,
#      'url': 'https://api.github.com/repos/OCA/l10n-spain/issues/comments/1176006545/reactions'},
#     'updated_at': '2022-07-06T09:36:44Z',
#     'url': 'https://api.github.com/repos/OCA/l10n-spain/issues/comments/1176006545',
#     'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/7165771?v=4',
#      'events_url': 'https://api.github.com/users/pedrobaeza/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/pedrobaeza/followers',
#      'following_url': 'https://api.github.com/users/pedrobaeza/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pedrobaeza/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/pedrobaeza',
#      'id': 7165771,
#      'login': 'pedrobaeza',
#      'node_id': 'MDQ6VXNlcjcxNjU3NzE=',
#      'organizations_url': 'https://api.github.com/users/pedrobaeza/orgs',
#      'received_events_url': 'https://api.github.com/users/pedrobaeza/received_events',
#      'repos_url': 'https://api.github.com/users/pedrobaeza/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/pedrobaeza/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pedrobaeza/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/pedrobaeza'}},
#    'issue': {'active_lock_reason': None,
#     'assignee': None,
#     'assignees': [],
#     'author_association': 'CONTRIBUTOR',
#     'body': 'Forward port of https://github.com/OCA/l10n-spain/pull/2333.',
#     'closed_at': None,
#     'comments': 1,
#     'comments_url': 'https://api.github.com/repos/OCA/l10n-spain/issues/2398/comments',
#     'created_at': '2022-07-06T09:21:51Z',
#     'draft': False,
#     'events_url': 'https://api.github.com/repos/OCA/l10n-spain/issues/2398/events',
#     'html_url': 'https://github.com/OCA/l10n-spain/pull/2398',
#     'id': 1295538372,
#     'labels': [],
#     'labels_url': 'https://api.github.com/repos/OCA/l10n-spain/issues/2398/labels{/name}',
#     'locked': False,
#     'milestone': {'closed_at': None,
#      'closed_issues': 58,
#      'created_at': '2021-10-17T10:18:15Z',
#      'creator': {'avatar_url': 'https://avatars.githubusercontent.com/u/8723280?v=4',
#       'events_url': 'https://api.github.com/users/OCA-git-bot/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/OCA-git-bot/followers',
#       'following_url': 'https://api.github.com/users/OCA-git-bot/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/OCA-git-bot/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/OCA-git-bot',
#       'id': 8723280,
#       'login': 'OCA-git-bot',
#       'node_id': 'MDQ6VXNlcjg3MjMyODA=',
#       'organizations_url': 'https://api.github.com/users/OCA-git-bot/orgs',
#       'received_events_url': 'https://api.github.com/users/OCA-git-bot/received_events',
#       'repos_url': 'https://api.github.com/users/OCA-git-bot/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/OCA-git-bot/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/OCA-git-bot/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/OCA-git-bot'},
#      'description': None,
#      'due_on': None,
#      'html_url': 'https://github.com/OCA/l10n-spain/milestone/9',
#      'id': 7260126,
#      'labels_url': 'https://api.github.com/repos/OCA/l10n-spain/milestones/9/labels',
#      'node_id': 'MI_kwDOAT85KM4Absfe',
#      'number': 9,
#      'open_issues': 5,
#      'state': 'open',
#      'title': '15.0',
#      'updated_at': '2022-07-06T09:35:59Z',
#      'url': 'https://api.github.com/repos/OCA/l10n-spain/milestones/9'},
#     'node_id': 'PR_kwDOAT85KM466-Ir',
#     'number': 2398,
#     'performed_via_github_app': None,
#     'pull_request': {'diff_url': 'https://github.com/OCA/l10n-spain/pull/2398.diff',
#      'html_url': 'https://github.com/OCA/l10n-spain/pull/2398',
#      'merged_at': None,
#      'patch_url': 'https://github.com/OCA/l10n-spain/pull/2398.patch',
#      'url': 'https://api.github.com/repos/OCA/l10n-spain/pulls/2398'},
#     'reactions': {'+1': 0,
#      '-1': 0,
#      'confused': 0,
#      'eyes': 0,
#      'heart': 0,
#      'hooray': 0,
#      'laugh': 0,
#      'rocket': 0,
#      'total_count': 0,
#      'url': 'https://api.github.com/repos/OCA/l10n-spain/issues/2398/reactions'},
#     'repository_url': 'https://api.github.com/repos/OCA/l10n-spain',
#     'state': 'open',
#     'state_reason': None,
#     'timeline_url': 'https://api.github.com/repos/OCA/l10n-spain/issues/2398/timeline',
#     'title': '[15.0][FIX] l10n_es_facturae: minor translation fixes (forward port)',
#     'updated_at': '2022-07-06T09:36:44Z',
#     'url': 'https://api.github.com/repos/OCA/l10n-spain/issues/2398',
#     'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/25005517?v=4',
#      'events_url': 'https://api.github.com/users/MiquelRForgeFlow/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/MiquelRForgeFlow/followers',
#      'following_url': 'https://api.github.com/users/MiquelRForgeFlow/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/MiquelRForgeFlow/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/MiquelRForgeFlow',
#      'id': 25005517,
#      'login': 'MiquelRForgeFlow',
#      'node_id': 'MDQ6VXNlcjI1MDA1NTE3',
#      'organizations_url': 'https://api.github.com/users/MiquelRForgeFlow/orgs',
#      'received_events_url': 'https://api.github.com/users/MiquelRForgeFlow/received_events',
#      'repos_url': 'https://api.github.com/users/MiquelRForgeFlow/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/MiquelRForgeFlow/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/MiquelRForgeFlow/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/MiquelRForgeFlow'}}},
#   'public': True,
#   'repo': {'id': 20920616,
#    'name': 'OCA/l10n-spain',
#    'url': 'https://api.github.com/repos/OCA/l10n-spain'},
#   'type': 'IssueCommentEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/108007279?',
#    'display_login': 'annthmu',
#    'gravatar_id': '',
#    'id': 108007279,
#    'login': 'annthmu',
#    'url': 'https://api.github.com/users/annthmu'},
#   'created_at': '2022-07-06T09:36:44Z',
#   'id': '22722876745',
#   'payload': {'action': 'closed',
#    'number': 2,
#    'pull_request': {'_links': {'comments': {'href': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/issues/2/comments'},
#      'commits': {'href': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/pulls/2/commits'},
#      'html': {'href': 'https://github.com/annthmu/MySSHRemoteRepo/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/issues/2'},
#      'review_comment': {'href': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/pulls/comments{/number}'},
#      'review_comments': {'href': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/pulls/2/comments'},
#      'self': {'href': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/pulls/2'},
#      'statuses': {'href': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/statuses/85a30d47273d0f404fb88cbf7f2936cad195a12d'}},
#     'active_lock_reason': None,
#     'additions': 5,
#     'assignee': None,
#     'assignees': [],
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'base': {'label': 'annthmu:master',
#      'ref': 'master',
#      'repo': {'allow_forking': True,
#       'archive_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/branches{/branch}',
#       'clone_url': 'https://github.com/annthmu/MySSHRemoteRepo.git',
#       'collaborators_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/contributors',
#       'created_at': '2022-07-04T10:01:52Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/deployments',
#       'description': None,
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/downloads',
#       'events_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/events',
#       'fork': False,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/forks',
#       'full_name': 'annthmu/MySSHRemoteRepo',
#       'git_commits_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/git/tags{/sha}',
#       'git_url': 'git://github.com/annthmu/MySSHRemoteRepo.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': None,
#       'hooks_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/hooks',
#       'html_url': 'https://github.com/annthmu/MySSHRemoteRepo',
#       'id': 510304946,
#       'is_template': False,
#       'issue_comment_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/labels{/name}',
#       'language': 'HTML',
#       'languages_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/languages',
#       'license': None,
#       'merges_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/merges',
#       'milestones_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/milestones{/number}',
#       'mirror_url': None,
#       'name': 'MySSHRemoteRepo',
#       'node_id': 'R_kgDOHmqisg',
#       'notifications_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/notifications{?since,all,participating}',
#       'open_issues': 0,
#       'open_issues_count': 0,
#       'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/108007279?v=4',
#        'events_url': 'https://api.github.com/users/annthmu/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/annthmu/followers',
#        'following_url': 'https://api.github.com/users/annthmu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/annthmu/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/annthmu',
#        'id': 108007279,
#        'login': 'annthmu',
#        'node_id': 'U_kgDOBnAPbw',
#        'organizations_url': 'https://api.github.com/users/annthmu/orgs',
#        'received_events_url': 'https://api.github.com/users/annthmu/received_events',
#        'repos_url': 'https://api.github.com/users/annthmu/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/annthmu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/annthmu/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/annthmu'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/pulls{/number}',
#       'pushed_at': '2022-07-06T09:36:43Z',
#       'releases_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/releases{/id}',
#       'size': 7,
#       'ssh_url': 'git@github.com:annthmu/MySSHRemoteRepo.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/stargazers',
#       'statuses_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/subscribers',
#       'subscription_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/subscription',
#       'svn_url': 'https://github.com/annthmu/MySSHRemoteRepo',
#       'tags_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/tags',
#       'teams_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/teams',
#       'topics': [],
#       'trees_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/git/trees{/sha}',
#       'updated_at': '2022-07-04T10:02:35Z',
#       'url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo',
#       'visibility': 'public',
#       'watchers': 0,
#       'watchers_count': 0,
#       'web_commit_signoff_required': False},
#      'sha': 'f2ca3c82c4e8e882a8936a604fd347fd87867260',
#      'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/108007279?v=4',
#       'events_url': 'https://api.github.com/users/annthmu/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/annthmu/followers',
#       'following_url': 'https://api.github.com/users/annthmu/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/annthmu/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/annthmu',
#       'id': 108007279,
#       'login': 'annthmu',
#       'node_id': 'U_kgDOBnAPbw',
#       'organizations_url': 'https://api.github.com/users/annthmu/orgs',
#       'received_events_url': 'https://api.github.com/users/annthmu/received_events',
#       'repos_url': 'https://api.github.com/users/annthmu/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/annthmu/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/annthmu/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/annthmu'}},
#     'body': None,
#     'changed_files': 1,
#     'closed_at': '2022-07-06T09:36:43Z',
#     'comments': 0,
#     'comments_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/issues/2/comments',
#     'commits': 1,
#     'commits_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/pulls/2/commits',
#     'created_at': '2022-07-06T09:36:34Z',
#     'deletions': 0,
#     'diff_url': 'https://github.com/annthmu/MySSHRemoteRepo/pull/2.diff',
#     'draft': False,
#     'head': {'label': 'annthmu:slave-three',
#      'ref': 'slave-three',
#      'repo': {'allow_forking': True,
#       'archive_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/branches{/branch}',
#       'clone_url': 'https://github.com/annthmu/MySSHRemoteRepo.git',
#       'collaborators_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/contributors',
#       'created_at': '2022-07-04T10:01:52Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/deployments',
#       'description': None,
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/downloads',
#       'events_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/events',
#       'fork': False,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/forks',
#       'full_name': 'annthmu/MySSHRemoteRepo',
#       'git_commits_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/git/tags{/sha}',
#       'git_url': 'git://github.com/annthmu/MySSHRemoteRepo.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': None,
#       'hooks_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/hooks',
#       'html_url': 'https://github.com/annthmu/MySSHRemoteRepo',
#       'id': 510304946,
#       'is_template': False,
#       'issue_comment_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/labels{/name}',
#       'language': 'HTML',
#       'languages_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/languages',
#       'license': None,
#       'merges_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/merges',
#       'milestones_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/milestones{/number}',
#       'mirror_url': None,
#       'name': 'MySSHRemoteRepo',
#       'node_id': 'R_kgDOHmqisg',
#       'notifications_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/notifications{?since,all,participating}',
#       'open_issues': 0,
#       'open_issues_count': 0,
#       'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/108007279?v=4',
#        'events_url': 'https://api.github.com/users/annthmu/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/annthmu/followers',
#        'following_url': 'https://api.github.com/users/annthmu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/annthmu/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/annthmu',
#        'id': 108007279,
#        'login': 'annthmu',
#        'node_id': 'U_kgDOBnAPbw',
#        'organizations_url': 'https://api.github.com/users/annthmu/orgs',
#        'received_events_url': 'https://api.github.com/users/annthmu/received_events',
#        'repos_url': 'https://api.github.com/users/annthmu/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/annthmu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/annthmu/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/annthmu'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/pulls{/number}',
#       'pushed_at': '2022-07-06T09:36:43Z',
#       'releases_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/releases{/id}',
#       'size': 7,
#       'ssh_url': 'git@github.com:annthmu/MySSHRemoteRepo.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/stargazers',
#       'statuses_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/subscribers',
#       'subscription_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/subscription',
#       'svn_url': 'https://github.com/annthmu/MySSHRemoteRepo',
#       'tags_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/tags',
#       'teams_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/teams',
#       'topics': [],
#       'trees_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/git/trees{/sha}',
#       'updated_at': '2022-07-04T10:02:35Z',
#       'url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo',
#       'visibility': 'public',
#       'watchers': 0,
#       'watchers_count': 0,
#       'web_commit_signoff_required': False},
#      'sha': '85a30d47273d0f404fb88cbf7f2936cad195a12d',
#      'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/108007279?v=4',
#       'events_url': 'https://api.github.com/users/annthmu/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/annthmu/followers',
#       'following_url': 'https://api.github.com/users/annthmu/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/annthmu/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/annthmu',
#       'id': 108007279,
#       'login': 'annthmu',
#       'node_id': 'U_kgDOBnAPbw',
#       'organizations_url': 'https://api.github.com/users/annthmu/orgs',
#       'received_events_url': 'https://api.github.com/users/annthmu/received_events',
#       'repos_url': 'https://api.github.com/users/annthmu/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/annthmu/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/annthmu/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/annthmu'}},
#     'html_url': 'https://github.com/annthmu/MySSHRemoteRepo/pull/2',
#     'id': 988554248,
#     'issue_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/issues/2',
#     'labels': [],
#     'locked': False,
#     'maintainer_can_modify': False,
#     'merge_commit_sha': '08e542ca1ae102851ef280c20b2a6d5ab7fb599e',
#     'mergeable': None,
#     'mergeable_state': 'unknown',
#     'merged': True,
#     'merged_at': '2022-07-06T09:36:43Z',
#     'merged_by': {'avatar_url': 'https://avatars.githubusercontent.com/u/108007279?v=4',
#      'events_url': 'https://api.github.com/users/annthmu/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/annthmu/followers',
#      'following_url': 'https://api.github.com/users/annthmu/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/annthmu/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/annthmu',
#      'id': 108007279,
#      'login': 'annthmu',
#      'node_id': 'U_kgDOBnAPbw',
#      'organizations_url': 'https://api.github.com/users/annthmu/orgs',
#      'received_events_url': 'https://api.github.com/users/annthmu/received_events',
#      'repos_url': 'https://api.github.com/users/annthmu/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/annthmu/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/annthmu/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/annthmu'},
#     'milestone': None,
#     'node_id': 'PR_kwDOHmqiss467CQI',
#     'number': 2,
#     'patch_url': 'https://github.com/annthmu/MySSHRemoteRepo/pull/2.patch',
#     'rebaseable': None,
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'review_comment_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/pulls/comments{/number}',
#     'review_comments': 0,
#     'review_comments_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/pulls/2/comments',
#     'state': 'closed',
#     'statuses_url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/statuses/85a30d47273d0f404fb88cbf7f2936cad195a12d',
#     'title': 'update dd.txt',
#     'updated_at': '2022-07-06T09:36:43Z',
#     'url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo/pulls/2',
#     'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/108007279?v=4',
#      'events_url': 'https://api.github.com/users/annthmu/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/annthmu/followers',
#      'following_url': 'https://api.github.com/users/annthmu/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/annthmu/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/annthmu',
#      'id': 108007279,
#      'login': 'annthmu',
#      'node_id': 'U_kgDOBnAPbw',
#      'organizations_url': 'https://api.github.com/users/annthmu/orgs',
#      'received_events_url': 'https://api.github.com/users/annthmu/received_events',
#      'repos_url': 'https://api.github.com/users/annthmu/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/annthmu/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/annthmu/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/annthmu'}}},
#   'public': True,
#   'repo': {'id': 510304946,
#    'name': 'annthmu/MySSHRemoteRepo',
#    'url': 'https://api.github.com/repos/annthmu/MySSHRemoteRepo'},
#   'type': 'PullRequestEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/92143682?',
#    'display_login': 'luob',
#    'gravatar_id': '',
#    'id': 92143682,
#    'login': 'luob',
#    'url': 'https://api.github.com/users/luob'},
#   'created_at': '2022-07-06T09:36:44Z',
#   'id': '22722876777',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/31228235?',
#    'gravatar_id': '',
#    'id': 31228235,
#    'login': 'fhmq',
#    'url': 'https://api.github.com/orgs/fhmq'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'repo': {'id': 101005917,
#    'name': 'fhmq/hmq',
#    'url': 'https://api.github.com/repos/fhmq/hmq'},
#   'type': 'WatchEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/28599136?',
#    'display_login': 'anajosep',
#    'gravatar_id': '',
#    'id': 28599136,
#    'login': 'anajosep',
#    'url': 'https://api.github.com/users/anajosep'},
#   'created_at': '2022-07-06T09:36:44Z',
#   'id': '22722876813',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/66847844?',
#    'gravatar_id': '',
#    'id': 66847844,
#    'login': 'verrazzano',
#    'url': 'https://api.github.com/orgs/verrazzano'},
#   'payload': {'description': 'Enterprise Container Platform for deploying cloud-native and traditional applications in multi-cloud and hybrid environments.',
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': 'anajosep/vz-6079-jaeger_ingress_support',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 273076580,
#    'name': 'verrazzano/verrazzano',
#    'url': 'https://api.github.com/repos/verrazzano/verrazzano'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/22548107?',
#    'display_login': 'bistakedar',
#    'gravatar_id': '',
#    'id': 22548107,
#    'login': 'bistakedar',
#    'url': 'https://api.github.com/users/bistakedar'},
#   'created_at': '2022-07-06T09:36:44Z',
#   'id': '22722876770',
#   'payload': {'before': 'faf6b803d90240cff1d3750b64f5eecad5cd349a',
#    'commits': [{'author': {'email': 'vineeth.vijayan@bistasolutions.com',
#       'name': 'Vineeth Vijayan'},
#      'distinct': True,
#      'message': '[FIX]Bg fix on stock backdate',
#      'sha': '8de73cc2261f07761341211e47244e47f0524fc1',
#      'url': 'https://api.github.com/repos/kjameson9777/Kevin-Jameson-PureAir/commits/8de73cc2261f07761341211e47244e47f0524fc1'}],
#    'distinct_size': 1,
#    'head': '8de73cc2261f07761341211e47244e47f0524fc1',
#    'push_id': 10359703858,
#    'ref': 'refs/heads/staging_01',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 501895200,
#    'name': 'kjameson9777/Kevin-Jameson-PureAir',
#    'url': 'https://api.github.com/repos/kjameson9777/Kevin-Jameson-PureAir'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'id': 49699333,
#    'login': 'dependabot[bot]',
#    'url': 'https://api.github.com/users/dependabot[bot]'},
#   'created_at': '2022-07-06T09:36:44Z',
#   'id': '22722876769',
#   'payload': {'pusher_type': 'user',
#    'ref': 'dependabot/npm_and_yarn/packages/generate/typescript-eslint/parser-5.30.5',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 360711704,
#    'name': 'rudxde/lerna-dockerize',
#    'url': 'https://api.github.com/repos/rudxde/lerna-dockerize'},
#   'type': 'DeleteEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/86595529?',
#    'display_login': 'abhinav-birru-07',
#    'gravatar_id': '',
#    'id': 86595529,
#    'login': 'abhinav-birru-07',
#    'url': 'https://api.github.com/users/abhinav-birru-07'},
#   'created_at': '2022-07-06T09:36:44Z',
#   'id': '22722876742',
#   'payload': {'description': 'A website that displays details of various movies, based on user input. The APIs are fetched from tmbd endpoint. Technologies Used : JavaScript',
#    'master_branch': 'main',
#    'pusher_type': 'user',
#    'ref': 'main',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 511074078,
#    'name': 'abhinav-birru-07/Movie-Site',
#    'url': 'https://api.github.com/repos/abhinav-birru-07/Movie-Site'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/96633653?',
#    'display_login': 'huda-maf',
#    'gravatar_id': '',
#    'id': 96633653,
#    'login': 'huda-maf',
#    'url': 'https://api.github.com/users/huda-maf'},
#   'created_at': '2022-07-06T09:36:44Z',
#   'id': '22722876709',
#   'payload': {'before': '58c098bc466c80ca309f546b2a7bc07a231180fb',
#    'commits': [{'author': {'email': 'huda.shafoot@maf.ae',
#       'name': 'HudaShafoot'},
#      'distinct': True,
#      'message': 'update',
#      'sha': '28ad159f2aee1ea4f7d08efe99d7e953ed19dcef',
#      'url': 'https://api.github.com/repos/huda-maf/DataStoreDemo/commits/28ad159f2aee1ea4f7d08efe99d7e953ed19dcef'}],
#    'distinct_size': 1,
#    'head': '28ad159f2aee1ea4f7d08efe99d7e953ed19dcef',
#    'push_id': 10359703761,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 505741027,
#    'name': 'huda-maf/DataStoreDemo',
#    'url': 'https://api.github.com/repos/huda-maf/DataStoreDemo'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/75851618?',
#    'display_login': 'DanCorderSoftwire',
#    'gravatar_id': '',
#    'id': 75851618,
#    'login': 'DanCorderSoftwire',
#    'url': 'https://api.github.com/users/DanCorderSoftwire'},
#   'created_at': '2022-07-06T09:36:44Z',
#   'id': '22722876698',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/19221939?',
#    'gravatar_id': '',
#    'id': 19221939,
#    'login': 'UKGovernmentBEIS',
#    'url': 'https://api.github.com/orgs/UKGovernmentBEIS'},
#   'payload': {'action': 'created',
#    'pull_request': {'_links': {'comments': {'href': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/issues/143/comments'},
#      'commits': {'href': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/pulls/143/commits'},
#      'html': {'href': 'https://github.com/UKGovernmentBEIS/beis-simple-energy-advice-beta/pull/143'},
#      'issue': {'href': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/issues/143'},
#      'review_comment': {'href': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/pulls/comments{/number}'},
#      'review_comments': {'href': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/pulls/143/comments'},
#      'self': {'href': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/pulls/143'},
#      'statuses': {'href': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/statuses/e6316813b8044f3a6bea0770b45f13cde9b0ce8b'}},
#     'active_lock_reason': None,
#     'assignee': None,
#     'assignees': [],
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'base': {'label': 'UKGovernmentBEIS:production',
#      'ref': 'production',
#      'repo': {'allow_forking': True,
#       'archive_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/branches{/branch}',
#       'clone_url': 'https://github.com/UKGovernmentBEIS/beis-simple-energy-advice-beta.git',
#       'collaborators_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/contributors',
#       'created_at': '2022-04-28T15:20:20Z',
#       'default_branch': 'main',
#       'deployments_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/deployments',
#       'description': None,
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/downloads',
#       'events_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/events',
#       'fork': False,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/forks',
#       'full_name': 'UKGovernmentBEIS/beis-simple-energy-advice-beta',
#       'git_commits_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/git/tags{/sha}',
#       'git_url': 'git://github.com/UKGovernmentBEIS/beis-simple-energy-advice-beta.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': None,
#       'hooks_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/hooks',
#       'html_url': 'https://github.com/UKGovernmentBEIS/beis-simple-energy-advice-beta',
#       'id': 486647054,
#       'is_template': False,
#       'issue_comment_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/labels{/name}',
#       'language': 'C#',
#       'languages_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/languages',
#       'license': None,
#       'merges_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/merges',
#       'milestones_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/milestones{/number}',
#       'mirror_url': None,
#       'name': 'beis-simple-energy-advice-beta',
#       'node_id': 'R_kgDOHQGlDg',
#       'notifications_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/notifications{?since,all,participating}',
#       'open_issues': 3,
#       'open_issues_count': 3,
#       'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/19221939?v=4',
#        'events_url': 'https://api.github.com/users/UKGovernmentBEIS/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/UKGovernmentBEIS/followers',
#        'following_url': 'https://api.github.com/users/UKGovernmentBEIS/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/UKGovernmentBEIS/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/UKGovernmentBEIS',
#        'id': 19221939,
#        'login': 'UKGovernmentBEIS',
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE5MjIxOTM5',
#        'organizations_url': 'https://api.github.com/users/UKGovernmentBEIS/orgs',
#        'received_events_url': 'https://api.github.com/users/UKGovernmentBEIS/received_events',
#        'repos_url': 'https://api.github.com/users/UKGovernmentBEIS/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/UKGovernmentBEIS/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/UKGovernmentBEIS/subscriptions',
#        'type': 'Organization',
#        'url': 'https://api.github.com/users/UKGovernmentBEIS'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/pulls{/number}',
#       'pushed_at': '2022-07-06T09:35:16Z',
#       'releases_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/releases{/id}',
#       'size': 3872,
#       'ssh_url': 'git@github.com:UKGovernmentBEIS/beis-simple-energy-advice-beta.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/stargazers',
#       'statuses_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/subscribers',
#       'subscription_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/subscription',
#       'svn_url': 'https://github.com/UKGovernmentBEIS/beis-simple-energy-advice-beta',
#       'tags_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/tags',
#       'teams_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/teams',
#       'topics': [],
#       'trees_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/git/trees{/sha}',
#       'updated_at': '2022-05-24T15:32:12Z',
#       'url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta',
#       'visibility': 'public',
#       'watchers': 0,
#       'watchers_count': 0,
#       'web_commit_signoff_required': False},
#      'sha': '53e14f21c871db86d06dba0eb8e3440dcb0e2cfa',
#      'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/19221939?v=4',
#       'events_url': 'https://api.github.com/users/UKGovernmentBEIS/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/UKGovernmentBEIS/followers',
#       'following_url': 'https://api.github.com/users/UKGovernmentBEIS/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/UKGovernmentBEIS/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/UKGovernmentBEIS',
#       'id': 19221939,
#       'login': 'UKGovernmentBEIS',
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE5MjIxOTM5',
#       'organizations_url': 'https://api.github.com/users/UKGovernmentBEIS/orgs',
#       'received_events_url': 'https://api.github.com/users/UKGovernmentBEIS/received_events',
#       'repos_url': 'https://api.github.com/users/UKGovernmentBEIS/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/UKGovernmentBEIS/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/UKGovernmentBEIS/subscriptions',
#       'type': 'Organization',
#       'url': 'https://api.github.com/users/UKGovernmentBEIS'}},
#     'body': 'tested locally\r\nminimal risk\r\nno docs required',
#     'closed_at': None,
#     'comments_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/issues/143/comments',
#     'commits_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/pulls/143/commits',
#     'created_at': '2022-07-06T09:30:49Z',
#     'diff_url': 'https://github.com/UKGovernmentBEIS/beis-simple-energy-advice-beta/pull/143.diff',
#     'draft': False,
#     'head': {'label': 'UKGovernmentBEIS:seabeta-608-amend-roof-flat-copy',
#      'ref': 'seabeta-608-amend-roof-flat-copy',
#      'repo': {'allow_forking': True,
#       'archive_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/branches{/branch}',
#       'clone_url': 'https://github.com/UKGovernmentBEIS/beis-simple-energy-advice-beta.git',
#       'collaborators_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/contributors',
#       'created_at': '2022-04-28T15:20:20Z',
#       'default_branch': 'main',
#       'deployments_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/deployments',
#       'description': None,
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/downloads',
#       'events_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/events',
#       'fork': False,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/forks',
#       'full_name': 'UKGovernmentBEIS/beis-simple-energy-advice-beta',
#       'git_commits_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/UKGovernmentBEIS/beis-simple-energy-advice-beta/git/tags{/sha}',
#       'git_url': 'git://github.com/UKGovernmentBEIS/beis-simple-energy-advice-beta.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
# ...
#     'closed_at': None,
#     'comments_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/issues/507/comments',
#     'commits_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/pulls/507/commits',
#     'created_at': '2022-07-05T15:04:20Z',
#     'diff_url': 'https://github.com/CLIMADA-project/climada_python/pull/507.diff',
#     'draft': True,
#     'head': {'label': 'CLIMADA-project:487-add-classmethod-to-hazard-for-reading-raster-like-data-from-netcdf-file',
#      'ref': '487-add-classmethod-to-hazard-for-reading-raster-like-data-from-netcdf-file',
#      'repo': {'allow_forking': True,
#       'archive_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/branches{/branch}',
#       'clone_url': 'https://github.com/CLIMADA-project/climada_python.git',
#       'collaborators_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/contributors',
#       'created_at': '2017-12-01T10:47:53Z',
#       'default_branch': 'main',
#       'deployments_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/deployments',
#       'description': 'Python (3.8+) version of CLIMADA',
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/downloads',
#       'events_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/events',
#       'fork': False,
#       'forks': 70,
#       'forks_count': 70,
#       'forks_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/forks',
#       'full_name': 'CLIMADA-project/climada_python',
#       'git_commits_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/git/tags{/sha}',
#       'git_url': 'git://github.com/CLIMADA-project/climada_python.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': '',
#       'hooks_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/hooks',
#       'html_url': 'https://github.com/CLIMADA-project/climada_python',
#       'id': 112729129,
#       'is_template': False,
#       'issue_comment_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/labels{/name}',
#       'language': 'Jupyter Notebook',
#       'languages_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/languages',
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'node_id': 'MDc6TGljZW5zZTk=',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0'},
#       'merges_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/merges',
#       'milestones_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/milestones{/number}',
#       'mirror_url': None,
#       'name': 'climada_python',
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTI3MjkxMjk=',
#       'notifications_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/notifications{?since,all,participating}',
#       'open_issues': 58,
#       'open_issues_count': 58,
#       'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/44439051?v=4',
#        'events_url': 'https://api.github.com/users/CLIMADA-project/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/CLIMADA-project/followers',
#        'following_url': 'https://api.github.com/users/CLIMADA-project/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/CLIMADA-project/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/CLIMADA-project',
#        'id': 44439051,
#        'login': 'CLIMADA-project',
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0NDM5MDUx',
#        'organizations_url': 'https://api.github.com/users/CLIMADA-project/orgs',
#        'received_events_url': 'https://api.github.com/users/CLIMADA-project/received_events',
#        'repos_url': 'https://api.github.com/users/CLIMADA-project/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/CLIMADA-project/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/CLIMADA-project/subscriptions',
#        'type': 'Organization',
#        'url': 'https://api.github.com/users/CLIMADA-project'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/pulls{/number}',
#       'pushed_at': '2022-07-06T08:22:26Z',
#       'releases_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/releases{/id}',
#       'size': 148607,
#       'ssh_url': 'git@github.com:CLIMADA-project/climada_python.git',
#       'stargazers_count': 160,
#       'stargazers_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/stargazers',
#       'statuses_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/subscribers',
#       'subscription_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/subscription',
#       'svn_url': 'https://github.com/CLIMADA-project/climada_python',
#       'tags_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/tags',
#       'teams_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/teams',
#       'topics': [],
#       'trees_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/git/trees{/sha}',
#       'updated_at': '2022-07-04T12:21:34Z',
#       'url': 'https://api.github.com/repos/CLIMADA-project/climada_python',
#       'visibility': 'public',
#       'watchers': 160,
#       'watchers_count': 160,
#       'web_commit_signoff_required': False},
#      'sha': '4a9a52065d3239ff2205ef0129f2009a85c4f40a',
#      'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/44439051?v=4',
#       'events_url': 'https://api.github.com/users/CLIMADA-project/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/CLIMADA-project/followers',
#       'following_url': 'https://api.github.com/users/CLIMADA-project/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/CLIMADA-project/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/CLIMADA-project',
#       'id': 44439051,
#       'login': 'CLIMADA-project',
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0NDM5MDUx',
#       'organizations_url': 'https://api.github.com/users/CLIMADA-project/orgs',
#       'received_events_url': 'https://api.github.com/users/CLIMADA-project/received_events',
#       'repos_url': 'https://api.github.com/users/CLIMADA-project/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/CLIMADA-project/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/CLIMADA-project/subscriptions',
#       'type': 'Organization',
#       'url': 'https://api.github.com/users/CLIMADA-project'}},
#     'html_url': 'https://github.com/CLIMADA-project/climada_python/pull/507',
#     'id': 987546108,
#     'issue_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/issues/507',
#     'labels': [],
#     'locked': False,
#     'merge_commit_sha': '5879f5d13bc9063449d59b9e44661593ebfead3e',
#     'merged_at': None,
#     'milestone': None,
#     'node_id': 'PR_kwDOBrgcKc463MH8',
#     'number': 507,
#     'patch_url': 'https://github.com/CLIMADA-project/climada_python/pull/507.patch',
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'review_comment_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/pulls/comments{/number}',
#     'review_comments_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/pulls/507/comments',
#     'state': 'open',
#     'statuses_url': 'https://api.github.com/repos/CLIMADA-project/climada_python/statuses/4a9a52065d3239ff2205ef0129f2009a85c4f40a',
#     'title': 'Add Hazard classmethod for loading NetCDF file',
#     'updated_at': '2022-07-06T09:36:43Z',
#     'url': 'https://api.github.com/repos/CLIMADA-project/climada_python/pulls/507',
#     'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/34276446?v=4',
#      'events_url': 'https://api.github.com/users/peanutfun/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/peanutfun/followers',
#      'following_url': 'https://api.github.com/users/peanutfun/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/peanutfun/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/peanutfun',
#      'id': 34276446,
#      'login': 'peanutfun',
#      'node_id': 'MDQ6VXNlcjM0Mjc2NDQ2',
#      'organizations_url': 'https://api.github.com/users/peanutfun/orgs',
#      'received_events_url': 'https://api.github.com/users/peanutfun/received_events',
#      'repos_url': 'https://api.github.com/users/peanutfun/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/peanutfun/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/peanutfun/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/peanutfun'}}},
#   'public': True,
#   'repo': {'id': 112729129,
#    'name': 'CLIMADA-project/climada_python',
#    'url': 'https://api.github.com/repos/CLIMADA-project/climada_python'},
#   'type': 'PullRequestReviewCommentEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'id': 41898282,
#    'login': 'github-actions[bot]',
#    'url': 'https://api.github.com/users/github-actions[bot]'},
#   'created_at': '2022-07-06T09:36:44Z',
#   'id': '22722876564',
#   'payload': {'before': '7803950c0f98b792b1960dfca90c2147d48352a9',
#    'commits': [{'author': {'email': 'blog-post-bot@example.com',
#       'name': 'blog-post-bot'},
#      'distinct': True,
#      'message': 'Updated readme with the latest stackOverflow data',
#      'sha': 'd981b099ba701b01eed7ed1ac956ca1c5771a60f',
#      'url': 'https://api.github.com/repos/SibeeshVenu/sibeeshvenu/commits/d981b099ba701b01eed7ed1ac956ca1c5771a60f'}],
#    'distinct_size': 1,
#    'head': 'd981b099ba701b01eed7ed1ac956ca1c5771a60f',
#    'push_id': 10359703729,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 280431841,
#    'name': 'SibeeshVenu/sibeeshvenu',
#    'url': 'https://api.github.com/repos/SibeeshVenu/sibeeshvenu'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/79517984?',
#    'display_login': 'Kookodile',
#    'gravatar_id': '',
#    'id': 79517984,
#    'login': 'Kookodile',
#    'url': 'https://api.github.com/users/Kookodile'},
#   'created_at': '2022-07-06T09:36:43Z',
#   'id': '22722876541',
#   'payload': {'before': '4300fab9a3309a4e08f23295c4eca1e028cf2a14',
#    'commits': [{'author': {'email': 'Basdeye@gmail.com',
#       'name': 'Bastien Deye'},
#      'distinct': True,
#      'message': 'YT Course -- pseudoCrud (timecode2h50) WIP',
#      'sha': '71fb0e4ecd0c3cc06586514962bc059cd06584b1',
#      'url': 'https://api.github.com/repos/Kookodile/react-training/commits/71fb0e4ecd0c3cc06586514962bc059cd06584b1'}],
#    'distinct_size': 1,
#    'head': '71fb0e4ecd0c3cc06586514962bc059cd06584b1',
#    'push_id': 10359703702,
#    'ref': 'refs/heads/YT-Course',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 510635212,
#    'name': 'Kookodile/react-training',
#    'url': 'https://api.github.com/repos/Kookodile/react-training'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'id': 49699333,
#    'login': 'dependabot[bot]',
#    'url': 'https://api.github.com/users/dependabot[bot]'},
#   'created_at': '2022-07-06T09:36:43Z',
#   'id': '22722876542',
#   'payload': {'description': None,
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': 'dependabot/bundler/rails-html-sanitizer-1.4.3',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 295810164,
#    'name': 'mathiusjohnson/jungle-project',
#    'url': 'https://api.github.com/repos/mathiusjohnson/jungle-project'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/75172011?',
#    'display_login': 'KaziSafeerZayan',
#    'gravatar_id': '',
#    'id': 75172011,
#    'login': 'KaziSafeerZayan',
#    'url': 'https://api.github.com/users/KaziSafeerZayan'},
#   'created_at': '2022-07-06T09:36:43Z',
#   'id': '22722876543',
#   'payload': {'before': '1868ce1cc418c67a1534ab186eacb95a35c7ae9f',
#    'commits': [{'author': {'email': '75172011+KaziSafeerZayan@users.noreply.github.com',
#       'name': 'KaziSafeerZayan'},
#      'distinct': True,
#      'message': 'README.md',
#      'sha': '5fceb99af24c992ceebf1cda9fb80c743e1be4ef',
#      'url': 'https://api.github.com/repos/KaziSafeerZayan/pythonProjects/commits/5fceb99af24c992ceebf1cda9fb80c743e1be4ef'}],
#    'distinct_size': 1,
#    'head': '5fceb99af24c992ceebf1cda9fb80c743e1be4ef',
#    'push_id': 10359703734,
#    'ref': 'refs/heads/main',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 511072421,
#    'name': 'KaziSafeerZayan/pythonProjects',
#    'url': 'https://api.github.com/repos/KaziSafeerZayan/pythonProjects'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/76098008?',
#    'display_login': 'CameronGuthrie',
#    'gravatar_id': '',
#    'id': 76098008,
#    'login': 'CameronGuthrie',
#    'url': 'https://api.github.com/users/CameronGuthrie'},
#   'created_at': '2022-07-06T09:36:43Z',
#   'id': '22722876529',
#   'payload': {'action': 'started'},
#   'public': True,
#   'repo': {'id': 290027104,
#    'name': 'darklinkpower/PlayniteExtensionsCollection',
#    'url': 'https://api.github.com/repos/darklinkpower/PlayniteExtensionsCollection'},
#   'type': 'WatchEvent'}]
